# %% [markdown]
# # Libraries

# %%
#! pip install pyautogen groq
! pip install "autogen-agentchat" "autogen-ext[openai]" rich
# Out:
# Collecting autogen-agentchat
#   Downloading autogen_agentchat-0.4.9.2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (13.9.4)
# Collecting autogen-ext[openai]
#   Downloading autogen_ext-0.4.9.2-py3-none-any.whl.metadata (6.2 kB)
# Collecting autogen-core==0.4.9.2 (from autogen-agentchat)
#   Downloading autogen_core-0.4.9.2-py3-none-any.whl.metadata (2.3 kB)
# Collecting jsonref~=1.1.0 (from autogen-core==0.4.9.2->autogen-agentchat)
#   Downloading jsonref-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: opentelemetry-api>=1.27.0 in /usr/local/lib/python3.11/dist-packages (from autogen-core==0.4.9.2->autogen-agentchat) (1.31.0)
# Requirement already satisfied: pillow>=11.0.0 in /usr/local/lib/python3.11/dist-packages (from autogen-core==0.4.9.2->autogen-agentchat) (11.1.0)
# Requirement already satisfied: protobuf~=5.29.3 in /usr/local/lib/python3.11/dist-packages (from autogen-core==0.4.9.2->autogen-agentchat) (5.29.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.10.0 in /usr/local/lib/python3.11/dist-packages (from autogen-core==0.4.9.2->autogen-agentchat) (2.10.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from autogen-core==0.4.9.2->autogen-agentchat) (4.12.2)
# Collecting aiofiles (from autogen-ext[openai])
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: openai>=1.52.2 in /usr/local/lib/python3.11/dist-packages (from autogen-ext[openai]) (1.66.3)
# Collecting tiktoken>=0.8.0 (from autogen-ext[openai])
#   Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich) (0.1.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.52.2->autogen-ext[openai]) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.52.2->autogen-ext[openai]) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.52.2->autogen-ext[openai]) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.52.2->autogen-ext[openai]) (0.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai>=1.52.2->autogen-ext[openai]) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai>=1.52.2->autogen-ext[openai]) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken>=0.8.0->autogen-ext[openai]) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from tiktoken>=0.8.0->autogen-ext[openai]) (2.32.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai>=1.52.2->autogen-ext[openai]) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai>=1.52.2->autogen-ext[openai]) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai>=1.52.2->autogen-ext[openai]) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.52.2->autogen-ext[openai]) (0.14.0)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api>=1.27.0->autogen-core==0.4.9.2->autogen-agentchat) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api>=1.27.0->autogen-core==0.4.9.2->autogen-agentchat) (8.6.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.4.9.2->autogen-agentchat) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.4.9.2->autogen-agentchat) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken>=0.8.0->autogen-ext[openai]) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken>=0.8.0->autogen-ext[openai]) (2.3.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated>=1.2.6->opentelemetry-api>=1.27.0->autogen-core==0.4.9.2->autogen-agentchat) (1.17.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.27.0->autogen-core==0.4.9.2->autogen-agentchat) (3.21.0)
# Downloading autogen_agentchat-0.4.9.2-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 5.5 MB/s eta 0:00:00
# Downloading autogen_core-0.4.9.2-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.9/83.9 kB 6.7 MB/s eta 0:00:00
# Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 42.8 MB/s eta 0:00:00
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading autogen_ext-0.4.9.2-py3-none-any.whl (234 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 234.2/234.2 kB 17.6 MB/s eta 0:00:00
# Downloading jsonref-1.1.0-py3-none-any.whl (9.4 kB)
# Installing collected packages: jsonref, aiofiles, tiktoken, autogen-core, autogen-ext, autogen-agentchat
# Successfully installed aiofiles-24.1.0 autogen-agentchat-0.4.9.2 autogen-core-0.4.9.2 autogen-ext-0.4.9.2 jsonref-1.1.0 tiktoken-0.9.0

# %% [markdown]
# # Prepare database

# %%
! pwd
# Out:
# /content

# %%
import json
import sqlite3

# Load JSON data from a file
with open("/content/tiki_extracted_products_small.json", "r", encoding="utf-8") as file:
    books = json.load(file)

# Connect to SQLite database (or create if not exists)
conn = sqlite3.connect("books.db")
cursor = conn.cursor()

# Create table if not exists
cursor.execute('''
    CREATE TABLE IF NOT EXISTS books (
        id INTEGER PRIMARY KEY,
        name TEXT,
        type TEXT,
        short_description TEXT,
        price INTEGER,
        original_price INTEGER,
        description TEXT,
        authors TEXT,
        categories TEXT
    )
''')

# Insert data into the table
for book in books:
    authors = book.get("authors", [])  # Get authors, default to empty list if missing
    authors_str = ", ".join(authors) if isinstance(authors, list) else str(authors)

    cursor.execute('''
        INSERT INTO books (id, name, type, short_description, price, original_price, description, authors, categories)
        VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
    ''', (
        book["id"],
        book["name"],
        book["type"],
        book["short_description"],
        book["price"],
        book["original_price"],
        book["description"],
        authors_str,
        book["categories"]
    ))

# Commit changes and close connection
conn.commit()
conn.close()

print("Books data saved successfully!")
# Out:
# Books data saved successfully!

# %%
import sqlite3
from datetime import datetime, timedelta
import random

# Connect to the SQLite database
conn = sqlite3.connect("books.db")
cursor = conn.cursor()

# Drop the orders table if it exists
cursor.execute("DROP TABLE IF EXISTS orders")

# Recreate the orders table
cursor.execute("""
    CREATE TABLE orders (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        customer_id INTEGER NOT NULL,
        book_id INTEGER NOT NULL,
        order_date TEXT NOT NULL,
        order_status TEXT CHECK(order_status IN ('Finished', 'In shipping')) NOT NULL
    )
""")

# Sample book IDs provided
book_ids = [416389, 706939, 56002080, 49181801, 54729138,
            275571603, 275571590, 275571109, 275153551, 275062854]

# Generate 10 sample orders for customer_id = 1
customer_id = 1
order_statuses = ["Finished", "In shipping"]
start_date = datetime(2024, 3, 1)  # Example start date

orders = []
for i, book_id in enumerate(book_ids):
    order_date = start_date + timedelta(days=i)  # Incremental order dates
    order_status = random.choice(order_statuses)  # Random status
    orders.append((customer_id, book_id, order_date.strftime("%Y-%m-%d"), order_status))

# Insert orders into the database
cursor.executemany("""
    INSERT INTO orders (customer_id, book_id, order_date, order_status)
    VALUES (?, ?, ?, ?)
""", orders)

# Commit and close connection
conn.commit()
conn.close()

print("Orders table created and populated successfully.")
# Out:
# Orders table created and populated successfully.

# %%
def query_database(query, db_name="books.db"):
    """
    Executes a SQL query on the given SQLite database and returns the results.

    :param db_name: str - Name of the SQLite database file (e.g., 'books.db')
    :param query: str - The SQL query to execute
    :return: list - Query results as a list of tuples
    """
    try:
        # Connect to the database
        conn = sqlite3.connect(db_name)
        cursor = conn.cursor()

        # Execute the query with optional parameters
        cursor.execute(query)

        # Fetch all results
        results = cursor.fetchall()

        # Close the connection
        conn.close()

        return results

    except sqlite3.Error as e:
        print(f"Database error: {e}")
        return None

# %%
query = "SELECT DISTINCT categories FROM books"
query_database(query)
# Out:
# [('Business & Economics',),
#  ('Personal Improvement',),
#  ("Children's Books",),
#  ('Dictionary',),
#  ('English Language Dictionary',),
#  ('Fiction - Literature',),
#  ('Psychology',),
#  ('Sự lão hóa - trẻ hỏa',),
#  ('Root',),
#  ('Nhà Sách Tiki',),
#  ('Biographies & Memoirs',),
#  ('Cẩm nang làm cha mẹ',),
#  ('Tiểu Thuyết Phương Tây',),
#  ('Luyện thi IELTS',),
#  ('Sách tiếng Việt',),
#  ('Mystery, Thriller & Suspense',),
#  ('Success',),
#  ('Books that will change your life',),
#  ("Children's Science Fiction & Fantasy",),
#  ('Science Fiction & Fantasy',),
#  ('Sách Y Học Hiện Đại',),
#  ('Châu Á',),
#  ('English Books',),
#  ('Sách Y Học Khác',),
#  ('Phật giáo',),
#  ('Sách khoa học',),
#  ('Travel & Holiday',),
#  ('Thể dục - thể thao - khác',),
#  ('Professions',),
#  ('Giáo trình đại học - cao đẳng - khác',),
#  ('Corporate Finance',),
#  ('Đại Trường Phát Educations',),
#  ('Kinh tế - Tài chính - Quản trị',),
#  ('Giáo trình Hán ngữ',),
#  ('Architecture',),
#  ('Kỹ Thuật khác',),
#  ('Lịch Sử Việt Nam',),
#  ('Từ Điển Việt - Anh',),
#  ('Cờ Tướng',),
#  ('Sách Phong Tục - Tập Quán Việt Nam',),
#  ('Từ Vựng Tiếng Anh',),
#  ('Nhạc lý',),
#  ('Luật Đất đai',),
#  ('Băng keo trong suốt',),
#  ('Lập Trình',),
#  ('Kinh tế chính trị',),
#  ('Triết học',),
#  ('Từ Điển Anh - Việt',),
#  ('Sách tài chính - khác',),
#  ('Sách học tiếng anh - khác',),
#  ('Kỹ thuật Nhiếp Ảnh',),
#  ('Sức khỏe tinh thần',),
#  ('Thiệp chúc mừng',),
#  ('Cookbooks, Food & Wine',),
#  ('Bookmark giấy',),
#  ('Máy Tính Khoa Học',),
#  ('Truyện ngắn - Tản văn - Tạp Văn Nước Ngoài',),
#  ('Thai giáo',),
#  ('Sách Kiến Thức - Kỹ Năng Cho Trẻ',),
#  ('Science - Technology',),
#  ('Arts & Photography Books',),
#  ('Sách tư duy - Kỹ năng sống',),
#  ('Tiểu Thuyết Phương Đông',),
#  ('Sách Hôn Nhân - Giới Tính',),
#  ('Sách chuyển động -Tương tác',),
#  ('Family Relationships',),
#  ('Văn học thiếu nhi',),
#  ('Danh nhân Nước Ngoài',),
#  ('Kiến thức - Bách khoa',),
#  ('Medical Books',),
#  ('Luyện thi TOEIC',),
#  ('Sách Làm Đẹp',),
#  ('Bài học kinh doanh',),
#  ('Chủ nghĩa xã hội - Tư tưởng Hồ Chí Minh',),
#  ('Tác Phẩm Kinh Điển Nước Ngoài',),
#  ('An toàn & Sơ cứu',),
#  ('Parenting & Relationships',),
#  ('Beverages & Wine',),
#  ('Internet - Computers',),
#  ('Mỹ thuật - Kiến trúc Thế giới',),
#  ('Mỹ thuật - Kiến trúc Việt Nam',),
#  ('Encyclopedia',),
#  ('Móc Khóa',),
#  ('Sách học Đàn Piano',),
#  ('Tiếng Anh Thiếu Nhi',),
#  ('Sách học tiếng hoa - khác',),
#  ('Máy tính điện tử để bàn',),
#  ('Bút gel',),
#  ('Religion - Spirituality',),
#  ('Đối Kháng',),
#  ('Âm nhạc - điện ảnh - khác',),
#  ('Yoga',),
#  ('Ngữ pháp Tiếng Hàn',),
#  ('Từ Điển Ngôn Ngữ Khác',),
#  ('Truyện ngắn - Tản văn - Tạp Văn Việt Nam',),
#  ('Phương pháp giáo dục Montessori',),
#  ('Luyện thi N2',),
#  ('Kỹ Thuật Điện',),
#  ('Truyện ngôn tình',),
#  ('Bưu ảnh - Postcard',),
#  ('Chạy bộ',),
#  ('Công Giáo',),
#  ('Tài chính cá nhân',),
#  ('Sách khởi nghiệp',),
#  ('Nghệ thuật sống',),
#  ('Sách học Đàn Guitar',),
#  ('Kỹ Thuật Ô Tô - Xe máy',),
#  ('Crafts & Hobbies',),
#  ('Thiết kế đồ họa',),
#  ('Sách Marketing - Bán hàng ',),
#  ('Từ Điển Anh - Anh',),
#  ('Sách quản trị nhân lực',),
#  ('Làm phim',),
#  ('Họa sĩ nổi tiếng',),
#  ('Triết Học phương Đông',),
#  ('Sách kỹ năng làm việc',),
#  ('History',),
#  ('Sách Luyện Thi Đại Học - Cao Đẳng',),
#  ('Dụng Cụ Văn Phòng',),
#  ('Sư phạm',),
#  ('Sách giáo dục',),
#  ('Truyện cổ tích',),
#  ('Luật Dân sự',),
#  ('Ingredients, Methods & Appliances',),
#  ('Business Leaders',),
#  ('Trang trí sinh nhật',),
#  ('Sách tham khảo cấp II',),
#  ("Children's & School Dictionary",),
#  ('Sách Nấu ăn',),
#  ('Châu Mỹ',),
#  ('Sách quản trị, lãnh đạo',),
#  ('Tạp Chí - Catalogue',),
#  ('Tin Học Văn Phòng',),
#  ('Phương pháp giáo dục con của người Do Thái',),
#  ('Ăn kiêng - Giảm cân',),
#  ('Thẻ luyện thi',),
#  ('Health, Fitness & Sports',),
#  ('Sách tham khảo cấp I',),
#  ('Sách Phong Tục - Tập Quán',),
#  ('Cọ vẽ chuyên nghiệp',),
#  ('Keo hồ dán đa năng',),
#  ('Từ Điển Tiếng Trung',),
#  ('Máy Tính Điện Tử',),
#  ('Politics & Current Affairs',),
#  ('Religion, Culture',),
#  ('History - Criticism',),
#  ('Economics',),
#  ('Foreign Language Study & Reference',),
#  ('Autobiography & Memoirs',),
#  ('Luật Lao động',),
#  ('Bút chì màu',),
#  ('Sáp dầu',),
#  ('Bút lông cứng',),
#  ('Bút lông bảng',),
#  ('Xóa kéo',),
#  ('Sách Tâm Lý Tuổi Teen',),
#  ('Sách Danh Nhân',),
#  ('Diets - Weight Loss - Nutrition',),
#  ('Philosophy',),
#  ('Encyclopedias & General Knowledge',),
#  ('Management - Leadership',),
#  ('Bút máy thay ruột',),
#  ('Truyện trinh thám',),
#  ('Environment',),
#  ('Other Arts',),
#  ('ELTs',),
#  ('Kinh Dịch Học',),
#  ('Tôn Giáo - Tâm Linh Khác',),
#  ('Gôm tẩy chì',),
#  ('Bút bi nước',),
#  ('Bút Chì Màu - Bút Lông Màu - Sáp Màu',),
#  ('Basic Medical Sciences',),
#  ('Historical, Political & Military',),
#  ('Ngữ pháp Tiếng Anh',),
#  ('Truyện Tranh, Manga, Comic',),
#  ('Comics & Graphic Novels',),
#  ('Mathematics',),
#  ('Others',),
#  ('Truyện tranh Ehon',),
#  ('Human & Biology Science',),
#  ('Fashion',),
#  ('Personal Finance',),
#  ('Classic',),
#  ('Magazines',),
#  ('Parenting',),
#  ('Astronomy & Space Science',),
#  ('Romance',),
#  ('Khung để bàn',),
#  ('Nursing',),
#  ('Sách Giáo Khoa Cấp 1',),
#  ('Arts & Literature',),
#  ('Trang trí giáng sinh',),
#  ('Giáo Trình Đại Học - Cao Đẳng',),
#  ('Lịch Sử Thế Giới',),
#  ('Baking - Desserts',),
#  ('Bảng từ trắng viết bút lông',),
#  ('Từ Điển Tiếng Việt',),
#  ('Classic Stories & Fairy Tales',),
#  ('Sách ăn dặm cho bé',),
#  ('Màu nước dạng tuýp',),
#  ('Kiến Thức Bách Khoa',),
#  ('Băng keo hai mặt',),
#  ('Tranh Truyện',),
#  ('Sách tham khảo cấp III',),
#  ('IELTS Books',),
#  ('Thể Dục - Thể Thao',),
#  ('Thơ',),
#  ('Sách tâm lý học - khác',),
#  ('Number, Shape & Colour',),
#  ('Phonic & Letter',),
#  ('Sách Y Học Cổ Truyền',),
#  ('Bút - Viết các loại',),
#  ('Sách Nông - Lâm - Ngư Nghiệp',),
#  ('Bút chì gỗ',),
#  ('Đầu tư',),
#  ('Light novel',),
#  ('Literary',),
#  ('Bilingual Dictionary',),
#  ('Bút gel - Bút nước',),
#  ('Sách Giáo Khoa Cấp 2',),
#  ('Bao giấy',),
#  ('Flashcards Cho Bé',),
#  ('Sách chiêm tinh - horoscope - khác',),
#  ('Tarot',),
#  ('Sổ tay dán gáy',),
#  ('Tô màu - Luyện chữ  ',),
#  ('Sách Tô Màu Dành Cho Người Lớn',),
#  ('Nature & Ecology',),
#  ('Home Living',),
#  ('Luật Hôn nhân và Gia đình',),
#  ('Chăm sóc sức khỏe em bé',),
#  ('Bookmark',),
#  ('Lĩnh vực khác',),
#  ('Asian Cooking',),
#  ('Truyện tranh thiếu nhi',),
#  ('Sản phẩm về giấy',),
#  ('Sổ tay bìa da',),
#  ('Elementary School: Grades 1 - 5',),
#  ('Contemporary',),
#  ('Phụ kiện - vật liệu trang trí - khác',),
#  ('Graphic Design',),
#  ('1980Books',),
#  ('May - Thêu - Thời Trang',),
#  ('Triết Học phương Tây',),
#  ('Sức khỏe phụ nữ',),
#  ('Middle School: Grades 6 - 9',),
#  ('Drawing & Painting',),
#  ('Luyện thi Tiếng Hoa HSK',),
#  ('Discovery & Exploration',),
#  ('Sách Phong Tục - Tập Quán Nước ngoài',),
#  ('Motivational',),
#  ('Picture books',),
#  ('Phong Thủy',),
#  ('Luật Nhà nước',),
#  ('Đạo đức - Kỹ năng sống',),
#  ('Kế toán',),
#  ('Danh nhân Việt Nam',),
#  ('Sách Giáo Khoa Cấp 3',),
#  ('Vegetarian & Vegan',),
#  ('Photography',),
#  ('Medicine',),
#  ('My first books',),
#  ('Relationship',),
#  ('Luyện thi N5',),
#  ('Túi Quà',),
#  ('Thể dục - Thể hình',),
#  ('Marketing - Sales',),
#  ('Family Health & Relationship',),
#  ('Quà tặng trang trí khác',),
#  ('Lau bảng',),
#  ('Social Sciences',),
#  ('Tiểu sử - Hồi ký',),
#  ('Văn phòng phẩm',),
#  ('Luật Hình sự',),
#  ('Luật Kinh tế',),
#  ('Truyện kinh dị',),
#  ('Phê Bình - Lý Luận Văn Học',),
#  ('Luật',),
#  ('Triết Học',),
#  ('Growing Up & Facts of Life',),
#  ('Family, friends and school',),
#  ('Sách Y Học',),
#  ('Sách Học Tiếng Hàn',),
#  ('Sách Tôn Giáo - Tâm Linh',),
#  ('Decorative Arts & Design',),
#  ('Sách Khoa Học - Kỹ Thuật',),
#  ('Sách hướng nghiệp',),
#  ('Sách Học Tiếng Anh',),
#  ('Lý Luận Chính Trị',),
#  ('Ngôn ngữ học',),
#  ('Chiêm Tinh Học',),
#  ('Sticker - Decal trang trí',),
#  ('Truyện dài',),
#  ('Vietnam',),
#  ('Drinks & Beverages',),
#  ('Sổ Agenda',),
#  ('Bút dạ quang',),
#  ('Sách Chữa Lành',),
#  ('Bàn cắt giấy',),
#  ('Sách chuyên đề',),
#  ('Chính trị đảng phái',),
#  ('Ngữ pháp Tiếng Nhật',),
#  ('Từ Vựng Tiếng Nhật',),
#  ('Babysitting, Day Care & Child Care',)]

# %% [markdown]
# # SQL_Agent

# %%
database_schema = {
    "books": {
        "description": "Table storing book details, including metadata and pricing information.",
        "columns": {
            "id": {"type": "INTEGER PRIMARY KEY", "description": "Unique identifier for the book."},
            "name": {"type": "TEXT", "description": "Title of the book."},
            "type": {"type": "TEXT", "description": "Genre or category of the book."},
            "short_description": {"type": "TEXT", "description": "Brief summary of the book."},
            "price": {"type": "REAL", "description": "Current selling price of the book."},
            "original_price": {"type": "REAL", "description": "Original price before discounts."},
            "description": {"type": "TEXT", "description": "Full description of the book."},
            "authors": {"type": "TEXT", "description": "List of authors, stored as a comma-separated string."},
            "categories": {"type": "TEXT", "description": "List of categories, stored as a comma-separated string."}
        }
    },
    "orders": {
        "description": "Table storing customer orders, including book purchases and order status.",
        "columns": {
            "id": {"type": "INTEGER PRIMARY KEY AUTOINCREMENT", "description": "Unique identifier for the order."},
            "customer_id": {"type": "INTEGER", "description": "Unique identifier of the customer placing the order."},
            "book_id": {
                "type": "INTEGER",
                "description": "Unique identifier of the book being ordered. References books(id)."
            },
            "order_date": {"type": "TEXT", "description": "Date when the order was placed (YYYY-MM-DD format)."},
            "order_status": {
                "type": "TEXT CHECK(order_status IN ('Finished', 'In shipping'))",
                "description": "Current status of the order. Can be 'Finished' or 'In shipping'."
            }
        }
    }
}

def generate_schema_prompt(schema):
    prompt = ""
    for table, details in schema.items():
        prompt += f"Table: {table} - {details['description']}\nColumns:\n"
        for column, col_details in details["columns"].items():
            prompt += f"- {column} ({col_details['type']}): {col_details['description']}\n"
        prompt += "\n"
    return prompt

# Generate prompt for the LLM
schema = generate_schema_prompt(database_schema)
print(schema)
# Out:
# Table: books - Table storing book details, including metadata and pricing information.
# Columns:
# - id (INTEGER PRIMARY KEY): Unique identifier for the book.
# - name (TEXT): Title of the book.
# - type (TEXT): Genre or category of the book.
# - short_description (TEXT): Brief summary of the book.
# - price (REAL): Current selling price of the book.
# - original_price (REAL): Original price before discounts.
# - description (TEXT): Full description of the book.
# - authors (TEXT): List of authors, stored as a comma-separated string.
# - categories (TEXT): List of categories, stored as a comma-separated string.
#
# Table: orders - Table storing customer orders, including book purchases and order status.
# Columns:
# - id (INTEGER PRIMARY KEY AUTOINCREMENT): Unique identifier for the order.
# - customer_id (INTEGER): Unique identifier of the customer placing the order.
# - book_id (INTEGER): Unique identifier of the book being ordered. References books(id).
# - order_date (TEXT): Date when the order was placed (YYYY-MM-DD format).
# - order_status (TEXT CHECK(order_status IN ('Finished', 'In shipping'))): Current status of the order. Can be 'Finished' or 'In shipping'.

# %%
schema_vie = """
Bảng: books - Bảng lưu trữ thông tin chi tiết về sách, bao gồm siêu dữ liệu và giá bán.
Các cột:
id (INTEGER PRIMARY KEY): Định danh duy nhất của sách.
name (TEXT): Tiêu đề của sách.
short_description (TEXT): Tóm tắt ngắn gọn về sách.
price (REAL): Giá bán hiện tại của sách.
original_price (REAL): Giá gốc trước khi giảm giá.
description (TEXT): Mô tả đầy đủ về sách.
authors (TEXT): Danh sách tác giả, được lưu dưới dạng chuỗi phân tách bằng dấu phẩy.
categories (TEXT): Danh sách danh mục, được lưu dưới dạng chuỗi phân tách bằng dấu phẩy.

Bảng: orders - Bảng lưu trữ đơn hàng của khách hàng, bao gồm thông tin mua sách và trạng thái đơn hàng.
Các cột:
id (INTEGER PRIMARY KEY AUTOINCREMENT): Định danh duy nhất của đơn hàng.
customer_id (INTEGER): Định danh duy nhất của khách hàng đặt hàng.
book_id (INTEGER): Định danh duy nhất của sách được đặt hàng. Tham chiếu đến books(id).
order_date (TEXT): Ngày đặt hàng (định dạng YYYY-MM-DD).
order_status (TEXT CHECK(order_status IN ('Finished', 'In shipping'))): Trạng thái hiện tại của đơn hàng. Có thể là 'Finished' (Hoàn thành) hoặc 'In shipping' (Đang vận chuyển).
"""

# %%
import asyncio
from autogen_core import CancellationToken
from autogen_ext.models.openai import OpenAIChatCompletionClient
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.messages import TextMessage
from autogen_agentchat.ui import Console
from autogen_core.tools import FunctionTool

sql_agent_system_message_vie = f"""
Bạn là một trợ lý hữu ích và có thể sử dụng công cụ SQL để truy vấn dữ liệu từ database

Dưới đây là một số điểm quan trọng bạn cần nhớ khi xây dựng truy vấn SQL:
- Khi cần lấy thông tin từ bảng orders, bạn phải lọc dữ liệu chỉ với customer_id = 1.
- Bạn có quyền truy cập vào lược đồ cơ sở dữ liệu sau:
{schema_vie}

Lưu ý:

Khi lọc sách, bạn nên sử dụng toán tử LIKE thay vì toán tử =.
Hãy cố gắng tránh thêm cột `short_description` và `description` vào phần SELECT, chỉ thêm khi thực sự cần thiết.
"""

# tools
def execute_sql_query(query: str):
    import sqlite3
    """
    Executes the given SQL query on the 'books.db' SQLite database and returns the results.

    Args:
        query (str): The SQL query to be executed.

    Returns:
        List[Tuple]: A list of tuples containing the rows returned by the query.
    """
    # Connect to the SQLite database
    conn = sqlite3.connect('/content/books.db')
    cursor = conn.cursor()

    try:
        # Execute the SQL query
        cursor.execute(query)
        # Fetch all results
        results = cursor.fetchall()
        return results
    except sqlite3.Error as e:
        # Handle SQL errors
        print(f"An error occurred: {e}")
        return []
    finally:
        # Close the database connection
        conn.close()

database_query_tool = FunctionTool(
    execute_sql_query, description="Truy vấn thông tin về sách từ database sử dụng SQL."
)


model_client = OpenAIChatCompletionClient(
    model="gpt-4o-mini",
    api_key='',
    seed=42,
    temperature=0)

sql_database_assistant = AssistantAgent(
    name="sql_database_assistant",
    description="Agent hỗ trợ trả lời các câu hỏi liên quan đến thông tin sách và thông tin mua hàng của khách hàng.",
    system_message=sql_agent_system_message_vie,
    model_client=model_client,
    tools=[database_query_tool],
    reflect_on_tool_use=True, # Set to True to have the model reflect on the tool use, set to False to return the tool call result directly.
)
user_input = "Giá của đơn hàng cuối cùng của tôi là bao nhiêu?"
response = await sql_database_assistant.on_messages([TextMessage(content=user_input, source="user")], CancellationToken())
print("Assistant:", response.chat_message.content)
print(response.inner_messages)
# Out:
# Assistant: Giá của đơn hàng cuối cùng của bạn là 81,880.
# [ToolCallRequestEvent(source='sql_database_assistant', models_usage=RequestUsage(prompt_tokens=518, completion_tokens=48), metadata={}, content=[FunctionCall(id='call_kcb4Hs0Z0GdS1pZkUIMYDTa8', arguments='{"query":"SELECT b.price FROM orders o JOIN books b ON o.book_id = b.id WHERE o.customer_id = 1 ORDER BY o.order_date DESC LIMIT 1;"}', name='execute_sql_query')], type='ToolCallRequestEvent'), ToolCallExecutionEvent(source='sql_database_assistant', models_usage=None, metadata={}, content=[FunctionExecutionResult(content='[(81880,)]', name='execute_sql_query', call_id='call_kcb4Hs0Z0GdS1pZkUIMYDTa8', is_error=False)], type='ToolCallExecutionEvent')]

# %% [markdown]
# # policy agent

# %%
! pip install langchain-community langchain -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 57.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 44.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.5 MB/s eta 0:00:00

# %%
! pip install chromadb sentence-transformers -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.1/611.1 kB 24.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 65.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 20.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 66.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 56.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.4/183.4 kB 12.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.2/65.2 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 kB 8.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 90.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 70.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 40.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 81.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.8/459.8 kB 24.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 69.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.6/452.6 kB 24.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.4 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from sentence_transformers import SentenceTransformer, CrossEncoder
from langchain.schema import Document
import os
import numpy as np
import unicodedata
from langchain.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
import chromadb
from datetime import datetime

# %%
# Load a single text file
file_path = r'drive/MyDrive/nlp/Policy/tikinow.txt'
loader = TextLoader(file_path, encoding='utf-8')
documents = loader.load()

for doc in documents:
    doc.page_content = unicodedata.normalize("NFKC", doc.page_content)

# %%
# Split text into chunks
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=400,
    chunk_overlap=100,
    separators=["\n\n", "\n", ".", " "],  # Tries splitting by paragraph, sentence, then word
    keep_separator=False
)

chunks = text_splitter.split_documents(documents)

# %%
for chunk in chunks:
    print(chunk.page_content)
    print('---------')
# Out:
# ﻿Dịch vụ giao hàng TikiNOW
#
#
# Khi cần Tiki có, khi khó Tiki giao! Giờ đây quý khách đã có thêm lựa chọn giao hàng khi mua sắm tại Tiki – Giao nhanh tại TP. Hồ Chí Minh/ Hà Nội với hàng trăm ngàn sản phẩm TikiNOW.
#
#
# 1. Đối tượng áp dụng:
# Các khách hàng có đăng nhập để đặt hàng và trong khu vực có hỗ trợ dịch vụ.
# ---------
# 1. Đối tượng áp dụng:
# Các khách hàng có đăng nhập để đặt hàng và trong khu vực có hỗ trợ dịch vụ.
#
#
# 2. Nội dung chi tiết:
#
#  NỘI DUNG         THÔNG TIN
#  Dấu hiệu nhận biết        NOW logo-primary.png
#  Phí vận chuyển         Giao Siêu Tốc 2H: 25.000 VND/3kg (+2.000 VND/ mỗi 0.5kg tiếp theo)
#  BookCare         Chỉ hỗ trợ đơn hàng dưới 20 quyển sách
# ---------
# 3. Khung giờ giao hàng:
# Quý khách vui lòng kiểm tra thời gian giao hàng dự kiến tại mục thông tin vận chuyển ở Bước "Thanh toán".
#
#
# - Nếu đơn hàng được đặt trước 18h: Sẽ được giao trong 2h-3h kể từ lúc đặt hàng.
#
#
# - Nếu đơn hàng được đặt sau 18h: Sẽ được giao trong buổi sáng tiếp theo.
#
#
# 4. Khu vực áp dụng dịch vụ:
# Quý khách khách có thể tham khảo khu vực áp dụng dịch vụ TikiNOW tại đây
# ---------
# Tiki đưa ra dịch vụ TikiNOW – Giao nhanh 2H với mong muốn phục vụ khách hàng tốt nhất, tuy nhiên thực tế vận hành có thể phát sinh những rủi ro ngoài ý muốn. Trong trường hợp này, quý khách hàng có bất kỳ khiếu nại gì vui lòng liên hệ bộ phận Chăm Sóc Khách Hàng của Tiki tại đây. Tiki cam kết sẽ kiểm tra đơn hàng và có chính sách giải quyết phù hợp với từng trường hợp cụ thể.
# ---------
# 5. Các câu hỏi thường gặp:
# a. Cách tìm kiếm sản phẩm hỗ trợ TikiNOW
#
#
# Quý khách có thể tìm kiếm và lọc theo TikiNOW gần 300.000 sản phẩm có thể được vận chuyển trong vòng 2 giờ, tại tất cả 2 thành phố lớn.
# Tiki đang bổ sung thêm nhiều sự lựa chọn khác cho TikiNOW mỗi ngày.
# ---------
# b. Tiki có áp dụng bọc sách BookCare cho đơn hàng đăng ký dịch vụ Giao Siêu Tốc không?
# Với đơn hàng dưới 20 quyển sách, quý khách có thể sử dụng dịch vụ bọc sách Bookcare với hình thức TikiNOW - Giao nhanh.
#
#
# c. Làm sao để tôi biết được sản phẩm mình muốn mua có áp dụng dịch vụ TikiNOW hay không?
# ---------
# c. Làm sao để tôi biết được sản phẩm mình muốn mua có áp dụng dịch vụ TikiNOW hay không?
#
#
# Những sản phẩm có áp dụng dịch vụ TikiNOW sẽ có logo TikiNOW ở bên cạnh hình sản phẩm (như hình) và thông tin về dịch vụ giao hàng TikiNOW trong phần thông tin sản phẩm, đồng thời quý khách cần chọn địa chỉ cần giao để xác định được sản phẩm có hỗ trợ TikiNOW không.
# Ngày hiệu lực chính sách từ 02/09/2017.
# ---------

# %%
# %cd /content/drive/MyDrive/nlp
# Out:
# /content/drive/MyDrive/nlp

# %%
import os
from sentence_transformers import SentenceTransformer
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Initialize ChromaDB client & collection
chroma_client = chromadb.PersistentClient(path="./chroma_db")
chroma_client.delete_collection("tiki_doc")

collection = chroma_client.get_or_create_collection("tiki_doc")

# Load embedding model
model = SentenceTransformer("sentence-transformers/all-MiniLM-L12-v2")

def chunk_and_store_document(file_path):
    """Reads a document, splits into chunks, embeds, and stores them in ChromaDB."""
    doc_name = os.path.splitext(os.path.basename(file_path))[0]  # Extract document name

    with open(file_path, "r", encoding="utf-8") as file:
        text = file.read()

    # Text chunking
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=400, chunk_overlap=100,
        separators=["\n\n", "\n", ".", " "], keep_separator=False
    )
    chunks = text_splitter.create_documents([text])  # Split into chunks

    # Embed and store each chunk separately
    for idx, chunk in enumerate(chunks):
        chunk_text = chunk.page_content
        embedding = model.encode(chunk_text).tolist()

        chunk_id = f"{doc_name}_{idx}"  # Unique ID for each chunk
        metadata = {
            "document_name": doc_name,
            "filename": file_path,
            "chunk_id": idx,
            "created_at": datetime.utcnow().isoformat(),  # Store timestamp
        }

        collection.add(
            ids=[chunk_id],
            embeddings=[embedding],
            documents=[chunk_text],
            metadatas=[metadata]  # Storing metadata only
        )

    print(f"✅ Stored {len(chunks)} chunks from '{file_path}' in ChromaDB!")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
import os

# Define the directory containing the text files
directory = "./Policy"

# Iterate through all .txt files in the directory
for file_name in os.listdir(directory):
    if file_name.endswith(".txt"):  # Process only .txt files
        file_path = os.path.join(directory, file_name)  # Get full file path
        doc_name = os.path.splitext(file_name)[0]  # Extract document name without extension

        print(f"Processing: {file_name} ...")  # Optional: Print progress
        chunk_and_store_document(file_path)  # Process the file

print("All text files have been processed and stored.")
# Out:
# Processing: theo_doi_doi_tra.txt ...
# ✅ Stored 3 chunks from './Policy/theo_doi_doi_tra.txt' in ChromaDB!
# Processing: kiem_hang.txt ...
# ✅ Stored 3 chunks from './Policy/kiem_hang.txt' in ChromaDB!
# Processing: kich_hoat_bao_hanh.txt ...
# ✅ Stored 5 chunks from './Policy/kich_hoat_bao_hanh.txt' in ChromaDB!
# Processing: huong_dan_dong_goi_hang_tra.txt ...
# ✅ Stored 9 chunks from './Policy/huong_dan_dong_goi_hang_tra.txt' in ChromaDB!
# Processing: noi_tiep_nhan_doi_tra.txt ...
# ✅ Stored 6 chunks from './Policy/noi_tiep_nhan_doi_tra.txt' in ChromaDB!
# Processing: huong_dan_doi_tra_online.txt ...
# ✅ Stored 6 chunks from './Policy/huong_dan_doi_tra_online.txt' in ChromaDB!
# Processing: huong_dan_dat_voucher.txt ...
# ✅ Stored 3 chunks from './Policy/huong_dan_dat_voucher.txt' in ChromaDB!
# Processing: qa_doi_tra.txt ...
# ✅ Stored 16 chunks from './Policy/qa_doi_tra.txt' in ChromaDB!
# Processing: san_pham_khong_doi_tra.txt ...
# ✅ Stored 5 chunks from './Policy/san_pham_khong_doi_tra.txt' in ChromaDB!
# Processing: hau_mai.txt ...
# ✅ Stored 30 chunks from './Policy/hau_mai.txt' in ChromaDB!
# Processing: giao_hang_nuoc_ngoai.txt ...
# ✅ Stored 12 chunks from './Policy/giao_hang_nuoc_ngoai.txt' in ChromaDB!
# Processing: bao_hanh.txt ...
# ✅ Stored 11 chunks from './Policy/bao_hanh.txt' in ChromaDB!
# Processing: hang_gia_200.txt ...
# ✅ Stored 9 chunks from './Policy/hang_gia_200.txt' in ChromaDB!
# Processing: doi_tra.txt ...
# ✅ Stored 18 chunks from './Policy/doi_tra.txt' in ChromaDB!
# Processing: giai_quyet_khieu_nai.txt ...
# ✅ Stored 14 chunks from './Policy/giai_quyet_khieu_nai.txt' in ChromaDB!
# Processing: huong_dan_dat_nhieu_sp.txt ...
# ✅ Stored 5 chunks from './Policy/huong_dan_dat_nhieu_sp.txt' in ChromaDB!
# Processing: huong_dan_dat_hang_website.txt ...
# ✅ Stored 12 chunks from './Policy/huong_dan_dat_hang_website.txt' in ChromaDB!
# Processing: abc.txt ...
# ✅ Stored 0 chunks from './Policy/abc.txt' in ChromaDB!
# Processing: huong_dan_dat_hang_app.txt ...
# ✅ Stored 12 chunks from './Policy/huong_dan_dat_hang_app.txt' in ChromaDB!
# Processing: tikifast.txt ...
# ✅ Stored 19 chunks from './Policy/tikifast.txt' in ChromaDB!
# Processing: tikinow.txt ...
# ✅ Stored 7 chunks from './Policy/tikinow.txt' in ChromaDB!
# Processing: xac_nhan_don_hang.txt ...
# ✅ Stored 0 chunks from './Policy/xac_nhan_don_hang.txt' in ChromaDB!
# All text files have been processed and stored.

# %%
chroma_client = chromadb.PersistentClient(path="./chroma_db")
collection = chroma_client.get_or_create_collection("tiki_doc")

# %%
chroma_client.list_collections()
# Out:
# ['tiki_doc']

# %%
def list_all_chunks():
    """Lists all stored chunks in ChromaDB with their full details."""

    results = collection.get(include=["documents", "embeddings", "metadatas"])  # Fetch everything

    if not results.get("ids"):
        print("No chunks found in ChromaDB.")
        return

    print(f"Found {len(results['ids'])} chunks in ChromaDB:\n")
    print("-" * 50)

    for i, chunk_id in enumerate(results["ids"]):
        metadata = results["metadatas"][i] if results.get("metadatas") and results["metadatas"] else {}

        print(f"Chunk ID: {chunk_id}")
        print(f"Metadata: {metadata}")
        print("-" * 50)

# Example Usage
list_all_chunks()  # Lists all stored chunks in the collection
# Out:
# Found 205 chunks in ChromaDB:
#
# --------------------------------------------------
# Chunk ID: theo_doi_doi_tra_0
# Metadata: {'chunk_id': 0, 'created_at': '2025-03-21T16:18:54.526016', 'document_name': 'theo_doi_doi_tra', 'filename': './Policy/theo_doi_doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: theo_doi_doi_tra_1
# Metadata: {'chunk_id': 1, 'created_at': '2025-03-21T16:18:54.894527', 'document_name': 'theo_doi_doi_tra', 'filename': './Policy/theo_doi_doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: theo_doi_doi_tra_2
# Metadata: {'chunk_id': 2, 'created_at': '2025-03-21T16:18:55.075508', 'document_name': 'theo_doi_doi_tra', 'filename': './Policy/theo_doi_doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: kiem_hang_0
# Metadata: {'chunk_id': 0, 'created_at': '2025-03-21T16:18:55.341878', 'document_name': 'kiem_hang', 'filename': './Policy/kiem_hang.txt'}
# --------------------------------------------------
# Chunk ID: kiem_hang_1
# Metadata: {'chunk_id': 1, 'created_at': '2025-03-21T16:18:55.859252', 'document_name': 'kiem_hang', 'filename': './Policy/kiem_hang.txt'}
# --------------------------------------------------
# Chunk ID: kiem_hang_2
# Metadata: {'chunk_id': 2, 'created_at': '2025-03-21T16:18:56.123619', 'document_name': 'kiem_hang', 'filename': './Policy/kiem_hang.txt'}
# --------------------------------------------------
# Chunk ID: kich_hoat_bao_hanh_0
# Metadata: {'chunk_id': 0, 'created_at': '2025-03-21T16:18:56.402196', 'document_name': 'kich_hoat_bao_hanh', 'filename': './Policy/kich_hoat_bao_hanh.txt'}
# --------------------------------------------------
# Chunk ID: kich_hoat_bao_hanh_1
# Metadata: {'chunk_id': 1, 'created_at': '2025-03-21T16:18:56.680594', 'document_name': 'kich_hoat_bao_hanh', 'filename': './Policy/kich_hoat_bao_hanh.txt'}
# --------------------------------------------------
# Chunk ID: kich_hoat_bao_hanh_2
# Metadata: {'chunk_id': 2, 'created_at': '2025-03-21T16:18:56.970498', 'document_name': 'kich_hoat_bao_hanh', 'filename': './Policy/kich_hoat_bao_hanh.txt'}
# --------------------------------------------------
# Chunk ID: kich_hoat_bao_hanh_3
# Metadata: {'chunk_id': 3, 'created_at': '2025-03-21T16:18:57.235190', 'document_name': 'kich_hoat_bao_hanh', 'filename': './Policy/kich_hoat_bao_hanh.txt'}
# --------------------------------------------------
# Chunk ID: kich_hoat_bao_hanh_4
# Metadata: {'chunk_id': 4, 'created_at': '2025-03-21T16:18:57.466000', 'document_name': 'kich_hoat_bao_hanh', 'filename': './Policy/kich_hoat_bao_hanh.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dong_goi_hang_tra_0
# Metadata: {'chunk_id': 0, 'created_at': '2025-03-21T16:18:57.591793', 'document_name': 'huong_dan_dong_goi_hang_tra', 'filename': './Policy/huong_dan_dong_goi_hang_tra.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dong_goi_hang_tra_1
# Metadata: {'chunk_id': 1, 'created_at': '2025-03-21T16:18:57.771388', 'document_name': 'huong_dan_dong_goi_hang_tra', 'filename': './Policy/huong_dan_dong_goi_hang_tra.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dong_goi_hang_tra_2
# Metadata: {'chunk_id': 2, 'created_at': '2025-03-21T16:18:57.916674', 'document_name': 'huong_dan_dong_goi_hang_tra', 'filename': './Policy/huong_dan_dong_goi_hang_tra.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dong_goi_hang_tra_3
# Metadata: {'chunk_id': 3, 'created_at': '2025-03-21T16:18:58.119549', 'document_name': 'huong_dan_dong_goi_hang_tra', 'filename': './Policy/huong_dan_dong_goi_hang_tra.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dong_goi_hang_tra_4
# Metadata: {'chunk_id': 4, 'created_at': '2025-03-21T16:18:58.299810', 'document_name': 'huong_dan_dong_goi_hang_tra', 'filename': './Policy/huong_dan_dong_goi_hang_tra.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dong_goi_hang_tra_5
# Metadata: {'chunk_id': 5, 'created_at': '2025-03-21T16:18:58.476208', 'document_name': 'huong_dan_dong_goi_hang_tra', 'filename': './Policy/huong_dan_dong_goi_hang_tra.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dong_goi_hang_tra_6
# Metadata: {'chunk_id': 6, 'created_at': '2025-03-21T16:18:58.556938', 'document_name': 'huong_dan_dong_goi_hang_tra', 'filename': './Policy/huong_dan_dong_goi_hang_tra.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dong_goi_hang_tra_7
# Metadata: {'chunk_id': 7, 'created_at': '2025-03-21T16:18:58.734131', 'document_name': 'huong_dan_dong_goi_hang_tra', 'filename': './Policy/huong_dan_dong_goi_hang_tra.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dong_goi_hang_tra_8
# Metadata: {'chunk_id': 8, 'created_at': '2025-03-21T16:18:58.861060', 'document_name': 'huong_dan_dong_goi_hang_tra', 'filename': './Policy/huong_dan_dong_goi_hang_tra.txt'}
# --------------------------------------------------
# Chunk ID: noi_tiep_nhan_doi_tra_0
# Metadata: {'chunk_id': 0, 'created_at': '2025-03-21T16:18:59.012746', 'document_name': 'noi_tiep_nhan_doi_tra', 'filename': './Policy/noi_tiep_nhan_doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: noi_tiep_nhan_doi_tra_1
# Metadata: {'chunk_id': 1, 'created_at': '2025-03-21T16:18:59.198883', 'document_name': 'noi_tiep_nhan_doi_tra', 'filename': './Policy/noi_tiep_nhan_doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: noi_tiep_nhan_doi_tra_2
# Metadata: {'chunk_id': 2, 'created_at': '2025-03-21T16:18:59.394897', 'document_name': 'noi_tiep_nhan_doi_tra', 'filename': './Policy/noi_tiep_nhan_doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: noi_tiep_nhan_doi_tra_3
# Metadata: {'chunk_id': 3, 'created_at': '2025-03-21T16:18:59.574080', 'document_name': 'noi_tiep_nhan_doi_tra', 'filename': './Policy/noi_tiep_nhan_doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: noi_tiep_nhan_doi_tra_4
# Metadata: {'chunk_id': 4, 'created_at': '2025-03-21T16:18:59.740392', 'document_name': 'noi_tiep_nhan_doi_tra', 'filename': './Policy/noi_tiep_nhan_doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: noi_tiep_nhan_doi_tra_5
# Metadata: {'chunk_id': 5, 'created_at': '2025-03-21T16:18:59.911454', 'document_name': 'noi_tiep_nhan_doi_tra', 'filename': './Policy/noi_tiep_nhan_doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_doi_tra_online_0
# Metadata: {'chunk_id': 0, 'created_at': '2025-03-21T16:19:00.087131', 'document_name': 'huong_dan_doi_tra_online', 'filename': './Policy/huong_dan_doi_tra_online.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_doi_tra_online_1
# Metadata: {'chunk_id': 1, 'created_at': '2025-03-21T16:19:00.206950', 'document_name': 'huong_dan_doi_tra_online', 'filename': './Policy/huong_dan_doi_tra_online.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_doi_tra_online_2
# Metadata: {'chunk_id': 2, 'created_at': '2025-03-21T16:19:00.379487', 'document_name': 'huong_dan_doi_tra_online', 'filename': './Policy/huong_dan_doi_tra_online.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_doi_tra_online_3
# Metadata: {'chunk_id': 3, 'created_at': '2025-03-21T16:19:00.577359', 'document_name': 'huong_dan_doi_tra_online', 'filename': './Policy/huong_dan_doi_tra_online.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_doi_tra_online_4
# Metadata: {'chunk_id': 4, 'created_at': '2025-03-21T16:19:00.779549', 'document_name': 'huong_dan_doi_tra_online', 'filename': './Policy/huong_dan_doi_tra_online.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_doi_tra_online_5
# Metadata: {'chunk_id': 5, 'created_at': '2025-03-21T16:19:00.960970', 'document_name': 'huong_dan_doi_tra_online', 'filename': './Policy/huong_dan_doi_tra_online.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dat_voucher_0
# Metadata: {'chunk_id': 0, 'created_at': '2025-03-21T16:19:01.148311', 'document_name': 'huong_dan_dat_voucher', 'filename': './Policy/huong_dan_dat_voucher.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dat_voucher_1
# Metadata: {'chunk_id': 1, 'created_at': '2025-03-21T16:19:01.275114', 'document_name': 'huong_dan_dat_voucher', 'filename': './Policy/huong_dan_dat_voucher.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dat_voucher_2
# Metadata: {'chunk_id': 2, 'created_at': '2025-03-21T16:19:01.456421', 'document_name': 'huong_dan_dat_voucher', 'filename': './Policy/huong_dan_dat_voucher.txt'}
# --------------------------------------------------
# Chunk ID: qa_doi_tra_0
# Metadata: {'chunk_id': 0, 'created_at': '2025-03-21T16:19:01.559474', 'document_name': 'qa_doi_tra', 'filename': './Policy/qa_doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: qa_doi_tra_1
# Metadata: {'chunk_id': 1, 'created_at': '2025-03-21T16:19:01.741576', 'document_name': 'qa_doi_tra', 'filename': './Policy/qa_doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: qa_doi_tra_2
# Metadata: {'chunk_id': 2, 'created_at': '2025-03-21T16:19:01.828188', 'document_name': 'qa_doi_tra', 'filename': './Policy/qa_doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: qa_doi_tra_3
# Metadata: {'chunk_id': 3, 'created_at': '2025-03-21T16:19:02.013304', 'document_name': 'qa_doi_tra', 'filename': './Policy/qa_doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: qa_doi_tra_4
# Metadata: {'chunk_id': 4, 'created_at': '2025-03-21T16:19:02.199142', 'document_name': 'qa_doi_tra', 'filename': './Policy/qa_doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: qa_doi_tra_5
# Metadata: {'chunk_id': 5, 'created_at': '2025-03-21T16:19:02.316917', 'document_name': 'qa_doi_tra', 'filename': './Policy/qa_doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: qa_doi_tra_6
# Metadata: {'chunk_id': 6, 'created_at': '2025-03-21T16:19:02.523994', 'document_name': 'qa_doi_tra', 'filename': './Policy/qa_doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: qa_doi_tra_7
# Metadata: {'chunk_id': 7, 'created_at': '2025-03-21T16:19:02.712608', 'document_name': 'qa_doi_tra', 'filename': './Policy/qa_doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: qa_doi_tra_8
# Metadata: {'chunk_id': 8, 'created_at': '2025-03-21T16:19:02.893596', 'document_name': 'qa_doi_tra', 'filename': './Policy/qa_doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: qa_doi_tra_9
# Metadata: {'chunk_id': 9, 'created_at': '2025-03-21T16:19:03.067973', 'document_name': 'qa_doi_tra', 'filename': './Policy/qa_doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: qa_doi_tra_10
# Metadata: {'chunk_id': 10, 'created_at': '2025-03-21T16:19:03.252219', 'document_name': 'qa_doi_tra', 'filename': './Policy/qa_doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: qa_doi_tra_11
# Metadata: {'chunk_id': 11, 'created_at': '2025-03-21T16:19:03.435598', 'document_name': 'qa_doi_tra', 'filename': './Policy/qa_doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: qa_doi_tra_12
# Metadata: {'chunk_id': 12, 'created_at': '2025-03-21T16:19:03.621538', 'document_name': 'qa_doi_tra', 'filename': './Policy/qa_doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: qa_doi_tra_13
# Metadata: {'chunk_id': 13, 'created_at': '2025-03-21T16:19:03.723529', 'document_name': 'qa_doi_tra', 'filename': './Policy/qa_doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: qa_doi_tra_14
# Metadata: {'chunk_id': 14, 'created_at': '2025-03-21T16:19:03.903444', 'document_name': 'qa_doi_tra', 'filename': './Policy/qa_doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: qa_doi_tra_15
# Metadata: {'chunk_id': 15, 'created_at': '2025-03-21T16:19:04.053236', 'document_name': 'qa_doi_tra', 'filename': './Policy/qa_doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: san_pham_khong_doi_tra_0
# Metadata: {'chunk_id': 0, 'created_at': '2025-03-21T16:19:04.174074', 'document_name': 'san_pham_khong_doi_tra', 'filename': './Policy/san_pham_khong_doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: san_pham_khong_doi_tra_1
# Metadata: {'chunk_id': 1, 'created_at': '2025-03-21T16:19:04.387028', 'document_name': 'san_pham_khong_doi_tra', 'filename': './Policy/san_pham_khong_doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: san_pham_khong_doi_tra_2
# Metadata: {'chunk_id': 2, 'created_at': '2025-03-21T16:19:04.555251', 'document_name': 'san_pham_khong_doi_tra', 'filename': './Policy/san_pham_khong_doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: san_pham_khong_doi_tra_3
# Metadata: {'chunk_id': 3, 'created_at': '2025-03-21T16:19:04.712359', 'document_name': 'san_pham_khong_doi_tra', 'filename': './Policy/san_pham_khong_doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: san_pham_khong_doi_tra_4
# Metadata: {'chunk_id': 4, 'created_at': '2025-03-21T16:19:04.894756', 'document_name': 'san_pham_khong_doi_tra', 'filename': './Policy/san_pham_khong_doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: hau_mai_0
# Metadata: {'chunk_id': 0, 'created_at': '2025-03-21T16:19:05.071509', 'document_name': 'hau_mai', 'filename': './Policy/hau_mai.txt'}
# --------------------------------------------------
# Chunk ID: hau_mai_1
# Metadata: {'chunk_id': 1, 'created_at': '2025-03-21T16:19:05.201848', 'document_name': 'hau_mai', 'filename': './Policy/hau_mai.txt'}
# --------------------------------------------------
# Chunk ID: hau_mai_2
# Metadata: {'chunk_id': 2, 'created_at': '2025-03-21T16:19:05.391023', 'document_name': 'hau_mai', 'filename': './Policy/hau_mai.txt'}
# --------------------------------------------------
# Chunk ID: hau_mai_3
# Metadata: {'chunk_id': 3, 'created_at': '2025-03-21T16:19:05.575108', 'document_name': 'hau_mai', 'filename': './Policy/hau_mai.txt'}
# --------------------------------------------------
# Chunk ID: hau_mai_4
# Metadata: {'chunk_id': 4, 'created_at': '2025-03-21T16:19:05.754758', 'document_name': 'hau_mai', 'filename': './Policy/hau_mai.txt'}
# --------------------------------------------------
# Chunk ID: hau_mai_5
# Metadata: {'chunk_id': 5, 'created_at': '2025-03-21T16:19:05.939622', 'document_name': 'hau_mai', 'filename': './Policy/hau_mai.txt'}
# --------------------------------------------------
# Chunk ID: hau_mai_6
# Metadata: {'chunk_id': 6, 'created_at': '2025-03-21T16:19:06.094073', 'document_name': 'hau_mai', 'filename': './Policy/hau_mai.txt'}
# --------------------------------------------------
# Chunk ID: hau_mai_7
# Metadata: {'chunk_id': 7, 'created_at': '2025-03-21T16:19:06.240799', 'document_name': 'hau_mai', 'filename': './Policy/hau_mai.txt'}
# --------------------------------------------------
# Chunk ID: hau_mai_8
# Metadata: {'chunk_id': 8, 'created_at': '2025-03-21T16:19:06.451985', 'document_name': 'hau_mai', 'filename': './Policy/hau_mai.txt'}
# --------------------------------------------------
# Chunk ID: hau_mai_9
# Metadata: {'chunk_id': 9, 'created_at': '2025-03-21T16:19:06.587220', 'document_name': 'hau_mai', 'filename': './Policy/hau_mai.txt'}
# --------------------------------------------------
# Chunk ID: hau_mai_10
# Metadata: {'chunk_id': 10, 'created_at': '2025-03-21T16:19:06.766976', 'document_name': 'hau_mai', 'filename': './Policy/hau_mai.txt'}
# --------------------------------------------------
# Chunk ID: hau_mai_11
# Metadata: {'chunk_id': 11, 'created_at': '2025-03-21T16:19:06.923981', 'document_name': 'hau_mai', 'filename': './Policy/hau_mai.txt'}
# --------------------------------------------------
# Chunk ID: hau_mai_12
# Metadata: {'chunk_id': 12, 'created_at': '2025-03-21T16:19:07.104355', 'document_name': 'hau_mai', 'filename': './Policy/hau_mai.txt'}
# --------------------------------------------------
# Chunk ID: hau_mai_13
# Metadata: {'chunk_id': 13, 'created_at': '2025-03-21T16:19:07.193787', 'document_name': 'hau_mai', 'filename': './Policy/hau_mai.txt'}
# --------------------------------------------------
# Chunk ID: hau_mai_14
# Metadata: {'chunk_id': 14, 'created_at': '2025-03-21T16:19:07.341518', 'document_name': 'hau_mai', 'filename': './Policy/hau_mai.txt'}
# --------------------------------------------------
# Chunk ID: hau_mai_15
# Metadata: {'chunk_id': 15, 'created_at': '2025-03-21T16:19:07.584577', 'document_name': 'hau_mai', 'filename': './Policy/hau_mai.txt'}
# --------------------------------------------------
# Chunk ID: hau_mai_16
# Metadata: {'chunk_id': 16, 'created_at': '2025-03-21T16:19:07.851431', 'document_name': 'hau_mai', 'filename': './Policy/hau_mai.txt'}
# --------------------------------------------------
# Chunk ID: hau_mai_17
# Metadata: {'chunk_id': 17, 'created_at': '2025-03-21T16:19:08.025089', 'document_name': 'hau_mai', 'filename': './Policy/hau_mai.txt'}
# --------------------------------------------------
# Chunk ID: hau_mai_18
# Metadata: {'chunk_id': 18, 'created_at': '2025-03-21T16:19:08.206775', 'document_name': 'hau_mai', 'filename': './Policy/hau_mai.txt'}
# --------------------------------------------------
# Chunk ID: hau_mai_19
# Metadata: {'chunk_id': 19, 'created_at': '2025-03-21T16:19:08.399698', 'document_name': 'hau_mai', 'filename': './Policy/hau_mai.txt'}
# --------------------------------------------------
# Chunk ID: hau_mai_20
# Metadata: {'chunk_id': 20, 'created_at': '2025-03-21T16:19:08.602558', 'document_name': 'hau_mai', 'filename': './Policy/hau_mai.txt'}
# --------------------------------------------------
# Chunk ID: hau_mai_21
# Metadata: {'chunk_id': 21, 'created_at': '2025-03-21T16:19:08.723642', 'document_name': 'hau_mai', 'filename': './Policy/hau_mai.txt'}
# --------------------------------------------------
# Chunk ID: hau_mai_22
# Metadata: {'chunk_id': 22, 'created_at': '2025-03-21T16:19:08.984840', 'document_name': 'hau_mai', 'filename': './Policy/hau_mai.txt'}
# --------------------------------------------------
# Chunk ID: hau_mai_23
# Metadata: {'chunk_id': 23, 'created_at': '2025-03-21T16:19:09.243394', 'document_name': 'hau_mai', 'filename': './Policy/hau_mai.txt'}
# --------------------------------------------------
# Chunk ID: hau_mai_24
# Metadata: {'chunk_id': 24, 'created_at': '2025-03-21T16:19:09.512801', 'document_name': 'hau_mai', 'filename': './Policy/hau_mai.txt'}
# --------------------------------------------------
# Chunk ID: hau_mai_25
# Metadata: {'chunk_id': 25, 'created_at': '2025-03-21T16:19:09.674968', 'document_name': 'hau_mai', 'filename': './Policy/hau_mai.txt'}
# --------------------------------------------------
# Chunk ID: hau_mai_26
# Metadata: {'chunk_id': 26, 'created_at': '2025-03-21T16:19:09.754520', 'document_name': 'hau_mai', 'filename': './Policy/hau_mai.txt'}
# --------------------------------------------------
# Chunk ID: hau_mai_27
# Metadata: {'chunk_id': 27, 'created_at': '2025-03-21T16:19:10.008156', 'document_name': 'hau_mai', 'filename': './Policy/hau_mai.txt'}
# --------------------------------------------------
# Chunk ID: hau_mai_28
# Metadata: {'chunk_id': 28, 'created_at': '2025-03-21T16:19:10.160823', 'document_name': 'hau_mai', 'filename': './Policy/hau_mai.txt'}
# --------------------------------------------------
# Chunk ID: hau_mai_29
# Metadata: {'chunk_id': 29, 'created_at': '2025-03-21T16:19:10.266215', 'document_name': 'hau_mai', 'filename': './Policy/hau_mai.txt'}
# --------------------------------------------------
# Chunk ID: giao_hang_nuoc_ngoai_0
# Metadata: {'chunk_id': 0, 'created_at': '2025-03-21T16:19:10.529850', 'document_name': 'giao_hang_nuoc_ngoai', 'filename': './Policy/giao_hang_nuoc_ngoai.txt'}
# --------------------------------------------------
# Chunk ID: giao_hang_nuoc_ngoai_1
# Metadata: {'chunk_id': 1, 'created_at': '2025-03-21T16:19:10.786114', 'document_name': 'giao_hang_nuoc_ngoai', 'filename': './Policy/giao_hang_nuoc_ngoai.txt'}
# --------------------------------------------------
# Chunk ID: giao_hang_nuoc_ngoai_2
# Metadata: {'chunk_id': 2, 'created_at': '2025-03-21T16:19:11.046998', 'document_name': 'giao_hang_nuoc_ngoai', 'filename': './Policy/giao_hang_nuoc_ngoai.txt'}
# --------------------------------------------------
# Chunk ID: giao_hang_nuoc_ngoai_3
# Metadata: {'chunk_id': 3, 'created_at': '2025-03-21T16:19:11.324150', 'document_name': 'giao_hang_nuoc_ngoai', 'filename': './Policy/giao_hang_nuoc_ngoai.txt'}
# --------------------------------------------------
# Chunk ID: giao_hang_nuoc_ngoai_4
# Metadata: {'chunk_id': 4, 'created_at': '2025-03-21T16:19:11.585248', 'document_name': 'giao_hang_nuoc_ngoai', 'filename': './Policy/giao_hang_nuoc_ngoai.txt'}
# --------------------------------------------------
# Chunk ID: giao_hang_nuoc_ngoai_5
# Metadata: {'chunk_id': 5, 'created_at': '2025-03-21T16:19:11.731206', 'document_name': 'giao_hang_nuoc_ngoai', 'filename': './Policy/giao_hang_nuoc_ngoai.txt'}
# --------------------------------------------------
# Chunk ID: giao_hang_nuoc_ngoai_6
# Metadata: {'chunk_id': 6, 'created_at': '2025-03-21T16:19:11.905774', 'document_name': 'giao_hang_nuoc_ngoai', 'filename': './Policy/giao_hang_nuoc_ngoai.txt'}
# --------------------------------------------------
# Chunk ID: giao_hang_nuoc_ngoai_7
# Metadata: {'chunk_id': 7, 'created_at': '2025-03-21T16:19:12.006767', 'document_name': 'giao_hang_nuoc_ngoai', 'filename': './Policy/giao_hang_nuoc_ngoai.txt'}
# --------------------------------------------------
# Chunk ID: giao_hang_nuoc_ngoai_8
# Metadata: {'chunk_id': 8, 'created_at': '2025-03-21T16:19:12.179793', 'document_name': 'giao_hang_nuoc_ngoai', 'filename': './Policy/giao_hang_nuoc_ngoai.txt'}
# --------------------------------------------------
# Chunk ID: giao_hang_nuoc_ngoai_9
# Metadata: {'chunk_id': 9, 'created_at': '2025-03-21T16:19:12.274688', 'document_name': 'giao_hang_nuoc_ngoai', 'filename': './Policy/giao_hang_nuoc_ngoai.txt'}
# --------------------------------------------------
# Chunk ID: giao_hang_nuoc_ngoai_10
# Metadata: {'chunk_id': 10, 'created_at': '2025-03-21T16:19:12.448104', 'document_name': 'giao_hang_nuoc_ngoai', 'filename': './Policy/giao_hang_nuoc_ngoai.txt'}
# --------------------------------------------------
# Chunk ID: giao_hang_nuoc_ngoai_11
# Metadata: {'chunk_id': 11, 'created_at': '2025-03-21T16:19:12.628132', 'document_name': 'giao_hang_nuoc_ngoai', 'filename': './Policy/giao_hang_nuoc_ngoai.txt'}
# --------------------------------------------------
# Chunk ID: bao_hanh_0
# Metadata: {'chunk_id': 0, 'created_at': '2025-03-21T16:19:12.718933', 'document_name': 'bao_hanh', 'filename': './Policy/bao_hanh.txt'}
# --------------------------------------------------
# Chunk ID: bao_hanh_1
# Metadata: {'chunk_id': 1, 'created_at': '2025-03-21T16:19:12.886290', 'document_name': 'bao_hanh', 'filename': './Policy/bao_hanh.txt'}
# --------------------------------------------------
# Chunk ID: bao_hanh_2
# Metadata: {'chunk_id': 2, 'created_at': '2025-03-21T16:19:13.060165', 'document_name': 'bao_hanh', 'filename': './Policy/bao_hanh.txt'}
# --------------------------------------------------
# Chunk ID: bao_hanh_3
# Metadata: {'chunk_id': 3, 'created_at': '2025-03-21T16:19:13.238421', 'document_name': 'bao_hanh', 'filename': './Policy/bao_hanh.txt'}
# --------------------------------------------------
# Chunk ID: bao_hanh_4
# Metadata: {'chunk_id': 4, 'created_at': '2025-03-21T16:19:13.419785', 'document_name': 'bao_hanh', 'filename': './Policy/bao_hanh.txt'}
# --------------------------------------------------
# Chunk ID: bao_hanh_5
# Metadata: {'chunk_id': 5, 'created_at': '2025-03-21T16:19:13.563573', 'document_name': 'bao_hanh', 'filename': './Policy/bao_hanh.txt'}
# --------------------------------------------------
# Chunk ID: bao_hanh_6
# Metadata: {'chunk_id': 6, 'created_at': '2025-03-21T16:19:13.747059', 'document_name': 'bao_hanh', 'filename': './Policy/bao_hanh.txt'}
# --------------------------------------------------
# Chunk ID: bao_hanh_7
# Metadata: {'chunk_id': 7, 'created_at': '2025-03-21T16:19:13.923367', 'document_name': 'bao_hanh', 'filename': './Policy/bao_hanh.txt'}
# --------------------------------------------------
# Chunk ID: bao_hanh_8
# Metadata: {'chunk_id': 8, 'created_at': '2025-03-21T16:19:14.100651', 'document_name': 'bao_hanh', 'filename': './Policy/bao_hanh.txt'}
# --------------------------------------------------
# Chunk ID: bao_hanh_9
# Metadata: {'chunk_id': 9, 'created_at': '2025-03-21T16:19:14.239690', 'document_name': 'bao_hanh', 'filename': './Policy/bao_hanh.txt'}
# --------------------------------------------------
# Chunk ID: bao_hanh_10
# Metadata: {'chunk_id': 10, 'created_at': '2025-03-21T16:19:14.415033', 'document_name': 'bao_hanh', 'filename': './Policy/bao_hanh.txt'}
# --------------------------------------------------
# Chunk ID: hang_gia_200_0
# Metadata: {'chunk_id': 0, 'created_at': '2025-03-21T16:19:14.593238', 'document_name': 'hang_gia_200', 'filename': './Policy/hang_gia_200.txt'}
# --------------------------------------------------
# Chunk ID: hang_gia_200_1
# Metadata: {'chunk_id': 1, 'created_at': '2025-03-21T16:19:14.756046', 'document_name': 'hang_gia_200', 'filename': './Policy/hang_gia_200.txt'}
# --------------------------------------------------
# Chunk ID: hang_gia_200_2
# Metadata: {'chunk_id': 2, 'created_at': '2025-03-21T16:19:14.901324', 'document_name': 'hang_gia_200', 'filename': './Policy/hang_gia_200.txt'}
# --------------------------------------------------
# Chunk ID: hang_gia_200_3
# Metadata: {'chunk_id': 3, 'created_at': '2025-03-21T16:19:14.979201', 'document_name': 'hang_gia_200', 'filename': './Policy/hang_gia_200.txt'}
# --------------------------------------------------
# Chunk ID: hang_gia_200_4
# Metadata: {'chunk_id': 4, 'created_at': '2025-03-21T16:19:15.187233', 'document_name': 'hang_gia_200', 'filename': './Policy/hang_gia_200.txt'}
# --------------------------------------------------
# Chunk ID: hang_gia_200_5
# Metadata: {'chunk_id': 5, 'created_at': '2025-03-21T16:19:15.272430', 'document_name': 'hang_gia_200', 'filename': './Policy/hang_gia_200.txt'}
# --------------------------------------------------
# Chunk ID: hang_gia_200_6
# Metadata: {'chunk_id': 6, 'created_at': '2025-03-21T16:19:15.445943', 'document_name': 'hang_gia_200', 'filename': './Policy/hang_gia_200.txt'}
# --------------------------------------------------
# Chunk ID: hang_gia_200_7
# Metadata: {'chunk_id': 7, 'created_at': '2025-03-21T16:19:15.618429', 'document_name': 'hang_gia_200', 'filename': './Policy/hang_gia_200.txt'}
# --------------------------------------------------
# Chunk ID: hang_gia_200_8
# Metadata: {'chunk_id': 8, 'created_at': '2025-03-21T16:19:15.755297', 'document_name': 'hang_gia_200', 'filename': './Policy/hang_gia_200.txt'}
# --------------------------------------------------
# Chunk ID: doi_tra_0
# Metadata: {'chunk_id': 0, 'created_at': '2025-03-21T16:19:15.919058', 'document_name': 'doi_tra', 'filename': './Policy/doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: doi_tra_1
# Metadata: {'chunk_id': 1, 'created_at': '2025-03-21T16:19:16.104208', 'document_name': 'doi_tra', 'filename': './Policy/doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: doi_tra_2
# Metadata: {'chunk_id': 2, 'created_at': '2025-03-21T16:19:16.272737', 'document_name': 'doi_tra', 'filename': './Policy/doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: doi_tra_3
# Metadata: {'chunk_id': 3, 'created_at': '2025-03-21T16:19:16.450160', 'document_name': 'doi_tra', 'filename': './Policy/doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: doi_tra_4
# Metadata: {'chunk_id': 4, 'created_at': '2025-03-21T16:19:16.630893', 'document_name': 'doi_tra', 'filename': './Policy/doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: doi_tra_5
# Metadata: {'chunk_id': 5, 'created_at': '2025-03-21T16:19:16.819785', 'document_name': 'doi_tra', 'filename': './Policy/doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: doi_tra_6
# Metadata: {'chunk_id': 6, 'created_at': '2025-03-21T16:19:16.998122', 'document_name': 'doi_tra', 'filename': './Policy/doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: doi_tra_7
# Metadata: {'chunk_id': 7, 'created_at': '2025-03-21T16:19:17.189001', 'document_name': 'doi_tra', 'filename': './Policy/doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: doi_tra_8
# Metadata: {'chunk_id': 8, 'created_at': '2025-03-21T16:19:17.372865', 'document_name': 'doi_tra', 'filename': './Policy/doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: doi_tra_9
# Metadata: {'chunk_id': 9, 'created_at': '2025-03-21T16:19:17.548969', 'document_name': 'doi_tra', 'filename': './Policy/doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: doi_tra_10
# Metadata: {'chunk_id': 10, 'created_at': '2025-03-21T16:19:17.682377', 'document_name': 'doi_tra', 'filename': './Policy/doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: doi_tra_11
# Metadata: {'chunk_id': 11, 'created_at': '2025-03-21T16:19:17.842835', 'document_name': 'doi_tra', 'filename': './Policy/doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: doi_tra_12
# Metadata: {'chunk_id': 12, 'created_at': '2025-03-21T16:19:17.993992', 'document_name': 'doi_tra', 'filename': './Policy/doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: doi_tra_13
# Metadata: {'chunk_id': 13, 'created_at': '2025-03-21T16:19:18.127824', 'document_name': 'doi_tra', 'filename': './Policy/doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: doi_tra_14
# Metadata: {'chunk_id': 14, 'created_at': '2025-03-21T16:19:18.291279', 'document_name': 'doi_tra', 'filename': './Policy/doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: doi_tra_15
# Metadata: {'chunk_id': 15, 'created_at': '2025-03-21T16:19:18.439733', 'document_name': 'doi_tra', 'filename': './Policy/doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: doi_tra_16
# Metadata: {'chunk_id': 16, 'created_at': '2025-03-21T16:19:18.621000', 'document_name': 'doi_tra', 'filename': './Policy/doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: doi_tra_17
# Metadata: {'chunk_id': 17, 'created_at': '2025-03-21T16:19:18.772907', 'document_name': 'doi_tra', 'filename': './Policy/doi_tra.txt'}
# --------------------------------------------------
# Chunk ID: giai_quyet_khieu_nai_0
# Metadata: {'chunk_id': 0, 'created_at': '2025-03-21T16:19:18.965534', 'document_name': 'giai_quyet_khieu_nai', 'filename': './Policy/giai_quyet_khieu_nai.txt'}
# --------------------------------------------------
# Chunk ID: giai_quyet_khieu_nai_1
# Metadata: {'chunk_id': 1, 'created_at': '2025-03-21T16:19:19.169344', 'document_name': 'giai_quyet_khieu_nai', 'filename': './Policy/giai_quyet_khieu_nai.txt'}
# --------------------------------------------------
# Chunk ID: giai_quyet_khieu_nai_2
# Metadata: {'chunk_id': 2, 'created_at': '2025-03-21T16:19:19.273612', 'document_name': 'giai_quyet_khieu_nai', 'filename': './Policy/giai_quyet_khieu_nai.txt'}
# --------------------------------------------------
# Chunk ID: giai_quyet_khieu_nai_3
# Metadata: {'chunk_id': 3, 'created_at': '2025-03-21T16:19:19.449742', 'document_name': 'giai_quyet_khieu_nai', 'filename': './Policy/giai_quyet_khieu_nai.txt'}
# --------------------------------------------------
# Chunk ID: giai_quyet_khieu_nai_4
# Metadata: {'chunk_id': 4, 'created_at': '2025-03-21T16:19:19.570708', 'document_name': 'giai_quyet_khieu_nai', 'filename': './Policy/giai_quyet_khieu_nai.txt'}
# --------------------------------------------------
# Chunk ID: giai_quyet_khieu_nai_5
# Metadata: {'chunk_id': 5, 'created_at': '2025-03-21T16:19:19.722479', 'document_name': 'giai_quyet_khieu_nai', 'filename': './Policy/giai_quyet_khieu_nai.txt'}
# --------------------------------------------------
# Chunk ID: giai_quyet_khieu_nai_6
# Metadata: {'chunk_id': 6, 'created_at': '2025-03-21T16:19:19.906242', 'document_name': 'giai_quyet_khieu_nai', 'filename': './Policy/giai_quyet_khieu_nai.txt'}
# --------------------------------------------------
# Chunk ID: giai_quyet_khieu_nai_7
# Metadata: {'chunk_id': 7, 'created_at': '2025-03-21T16:19:20.072321', 'document_name': 'giai_quyet_khieu_nai', 'filename': './Policy/giai_quyet_khieu_nai.txt'}
# --------------------------------------------------
# Chunk ID: giai_quyet_khieu_nai_8
# Metadata: {'chunk_id': 8, 'created_at': '2025-03-21T16:19:20.209788', 'document_name': 'giai_quyet_khieu_nai', 'filename': './Policy/giai_quyet_khieu_nai.txt'}
# --------------------------------------------------
# Chunk ID: giai_quyet_khieu_nai_9
# Metadata: {'chunk_id': 9, 'created_at': '2025-03-21T16:19:20.384188', 'document_name': 'giai_quyet_khieu_nai', 'filename': './Policy/giai_quyet_khieu_nai.txt'}
# --------------------------------------------------
# Chunk ID: giai_quyet_khieu_nai_10
# Metadata: {'chunk_id': 10, 'created_at': '2025-03-21T16:19:20.507772', 'document_name': 'giai_quyet_khieu_nai', 'filename': './Policy/giai_quyet_khieu_nai.txt'}
# --------------------------------------------------
# Chunk ID: giai_quyet_khieu_nai_11
# Metadata: {'chunk_id': 11, 'created_at': '2025-03-21T16:19:20.681832', 'document_name': 'giai_quyet_khieu_nai', 'filename': './Policy/giai_quyet_khieu_nai.txt'}
# --------------------------------------------------
# Chunk ID: giai_quyet_khieu_nai_12
# Metadata: {'chunk_id': 12, 'created_at': '2025-03-21T16:19:20.861882', 'document_name': 'giai_quyet_khieu_nai', 'filename': './Policy/giai_quyet_khieu_nai.txt'}
# --------------------------------------------------
# Chunk ID: giai_quyet_khieu_nai_13
# Metadata: {'chunk_id': 13, 'created_at': '2025-03-21T16:19:20.955667', 'document_name': 'giai_quyet_khieu_nai', 'filename': './Policy/giai_quyet_khieu_nai.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dat_nhieu_sp_0
# Metadata: {'chunk_id': 0, 'created_at': '2025-03-21T16:19:21.111709', 'document_name': 'huong_dan_dat_nhieu_sp', 'filename': './Policy/huong_dan_dat_nhieu_sp.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dat_nhieu_sp_1
# Metadata: {'chunk_id': 1, 'created_at': '2025-03-21T16:19:21.258912', 'document_name': 'huong_dan_dat_nhieu_sp', 'filename': './Policy/huong_dan_dat_nhieu_sp.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dat_nhieu_sp_2
# Metadata: {'chunk_id': 2, 'created_at': '2025-03-21T16:19:21.427820', 'document_name': 'huong_dan_dat_nhieu_sp', 'filename': './Policy/huong_dan_dat_nhieu_sp.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dat_nhieu_sp_3
# Metadata: {'chunk_id': 3, 'created_at': '2025-03-21T16:19:21.555045', 'document_name': 'huong_dan_dat_nhieu_sp', 'filename': './Policy/huong_dan_dat_nhieu_sp.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dat_nhieu_sp_4
# Metadata: {'chunk_id': 4, 'created_at': '2025-03-21T16:19:21.747551', 'document_name': 'huong_dan_dat_nhieu_sp', 'filename': './Policy/huong_dan_dat_nhieu_sp.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dat_hang_website_0
# Metadata: {'chunk_id': 0, 'created_at': '2025-03-21T16:19:21.952343', 'document_name': 'huong_dan_dat_hang_website', 'filename': './Policy/huong_dan_dat_hang_website.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dat_hang_website_1
# Metadata: {'chunk_id': 1, 'created_at': '2025-03-21T16:19:22.211530', 'document_name': 'huong_dan_dat_hang_website', 'filename': './Policy/huong_dan_dat_hang_website.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dat_hang_website_2
# Metadata: {'chunk_id': 2, 'created_at': '2025-03-21T16:19:22.390990', 'document_name': 'huong_dan_dat_hang_website', 'filename': './Policy/huong_dan_dat_hang_website.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dat_hang_website_3
# Metadata: {'chunk_id': 3, 'created_at': '2025-03-21T16:19:22.632207', 'document_name': 'huong_dan_dat_hang_website', 'filename': './Policy/huong_dan_dat_hang_website.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dat_hang_website_4
# Metadata: {'chunk_id': 4, 'created_at': '2025-03-21T16:19:22.867151', 'document_name': 'huong_dan_dat_hang_website', 'filename': './Policy/huong_dan_dat_hang_website.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dat_hang_website_5
# Metadata: {'chunk_id': 5, 'created_at': '2025-03-21T16:19:23.065805', 'document_name': 'huong_dan_dat_hang_website', 'filename': './Policy/huong_dan_dat_hang_website.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dat_hang_website_6
# Metadata: {'chunk_id': 6, 'created_at': '2025-03-21T16:19:23.344252', 'document_name': 'huong_dan_dat_hang_website', 'filename': './Policy/huong_dan_dat_hang_website.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dat_hang_website_7
# Metadata: {'chunk_id': 7, 'created_at': '2025-03-21T16:19:23.598501', 'document_name': 'huong_dan_dat_hang_website', 'filename': './Policy/huong_dan_dat_hang_website.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dat_hang_website_8
# Metadata: {'chunk_id': 8, 'created_at': '2025-03-21T16:19:23.860164', 'document_name': 'huong_dan_dat_hang_website', 'filename': './Policy/huong_dan_dat_hang_website.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dat_hang_website_9
# Metadata: {'chunk_id': 9, 'created_at': '2025-03-21T16:19:24.121606', 'document_name': 'huong_dan_dat_hang_website', 'filename': './Policy/huong_dan_dat_hang_website.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dat_hang_website_10
# Metadata: {'chunk_id': 10, 'created_at': '2025-03-21T16:19:24.306514', 'document_name': 'huong_dan_dat_hang_website', 'filename': './Policy/huong_dan_dat_hang_website.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dat_hang_website_11
# Metadata: {'chunk_id': 11, 'created_at': '2025-03-21T16:19:24.528372', 'document_name': 'huong_dan_dat_hang_website', 'filename': './Policy/huong_dan_dat_hang_website.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dat_hang_app_0
# Metadata: {'chunk_id': 0, 'created_at': '2025-03-21T16:19:24.727142', 'document_name': 'huong_dan_dat_hang_app', 'filename': './Policy/huong_dan_dat_hang_app.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dat_hang_app_1
# Metadata: {'chunk_id': 1, 'created_at': '2025-03-21T16:19:24.997139', 'document_name': 'huong_dan_dat_hang_app', 'filename': './Policy/huong_dan_dat_hang_app.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dat_hang_app_2
# Metadata: {'chunk_id': 2, 'created_at': '2025-03-21T16:19:25.210887', 'document_name': 'huong_dan_dat_hang_app', 'filename': './Policy/huong_dan_dat_hang_app.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dat_hang_app_3
# Metadata: {'chunk_id': 3, 'created_at': '2025-03-21T16:19:25.434463', 'document_name': 'huong_dan_dat_hang_app', 'filename': './Policy/huong_dan_dat_hang_app.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dat_hang_app_4
# Metadata: {'chunk_id': 4, 'created_at': '2025-03-21T16:19:25.659133', 'document_name': 'huong_dan_dat_hang_app', 'filename': './Policy/huong_dan_dat_hang_app.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dat_hang_app_5
# Metadata: {'chunk_id': 5, 'created_at': '2025-03-21T16:19:25.836577', 'document_name': 'huong_dan_dat_hang_app', 'filename': './Policy/huong_dan_dat_hang_app.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dat_hang_app_6
# Metadata: {'chunk_id': 6, 'created_at': '2025-03-21T16:19:26.009805', 'document_name': 'huong_dan_dat_hang_app', 'filename': './Policy/huong_dan_dat_hang_app.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dat_hang_app_7
# Metadata: {'chunk_id': 7, 'created_at': '2025-03-21T16:19:26.169306', 'document_name': 'huong_dan_dat_hang_app', 'filename': './Policy/huong_dan_dat_hang_app.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dat_hang_app_8
# Metadata: {'chunk_id': 8, 'created_at': '2025-03-21T16:19:26.343069', 'document_name': 'huong_dan_dat_hang_app', 'filename': './Policy/huong_dan_dat_hang_app.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dat_hang_app_9
# Metadata: {'chunk_id': 9, 'created_at': '2025-03-21T16:19:26.516766', 'document_name': 'huong_dan_dat_hang_app', 'filename': './Policy/huong_dan_dat_hang_app.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dat_hang_app_10
# Metadata: {'chunk_id': 10, 'created_at': '2025-03-21T16:19:26.647842', 'document_name': 'huong_dan_dat_hang_app', 'filename': './Policy/huong_dan_dat_hang_app.txt'}
# --------------------------------------------------
# Chunk ID: huong_dan_dat_hang_app_11
# Metadata: {'chunk_id': 11, 'created_at': '2025-03-21T16:19:26.786849', 'document_name': 'huong_dan_dat_hang_app', 'filename': './Policy/huong_dan_dat_hang_app.txt'}
# --------------------------------------------------
# Chunk ID: tikifast_0
# Metadata: {'chunk_id': 0, 'created_at': '2025-03-21T16:19:26.937241', 'document_name': 'tikifast', 'filename': './Policy/tikifast.txt'}
# --------------------------------------------------
# Chunk ID: tikifast_1
# Metadata: {'chunk_id': 1, 'created_at': '2025-03-21T16:19:27.107741', 'document_name': 'tikifast', 'filename': './Policy/tikifast.txt'}
# --------------------------------------------------
# Chunk ID: tikifast_2
# Metadata: {'chunk_id': 2, 'created_at': '2025-03-21T16:19:27.288042', 'document_name': 'tikifast', 'filename': './Policy/tikifast.txt'}
# --------------------------------------------------
# Chunk ID: tikifast_3
# Metadata: {'chunk_id': 3, 'created_at': '2025-03-21T16:19:27.467238', 'document_name': 'tikifast', 'filename': './Policy/tikifast.txt'}
# --------------------------------------------------
# Chunk ID: tikifast_4
# Metadata: {'chunk_id': 4, 'created_at': '2025-03-21T16:19:27.644708', 'document_name': 'tikifast', 'filename': './Policy/tikifast.txt'}
# --------------------------------------------------
# Chunk ID: tikifast_5
# Metadata: {'chunk_id': 5, 'created_at': '2025-03-21T16:19:27.816756', 'document_name': 'tikifast', 'filename': './Policy/tikifast.txt'}
# --------------------------------------------------
# Chunk ID: tikifast_6
# Metadata: {'chunk_id': 6, 'created_at': '2025-03-21T16:19:28.008108', 'document_name': 'tikifast', 'filename': './Policy/tikifast.txt'}
# --------------------------------------------------
# Chunk ID: tikifast_7
# Metadata: {'chunk_id': 7, 'created_at': '2025-03-21T16:19:28.175925', 'document_name': 'tikifast', 'filename': './Policy/tikifast.txt'}
# --------------------------------------------------
# Chunk ID: tikifast_8
# Metadata: {'chunk_id': 8, 'created_at': '2025-03-21T16:19:28.352373', 'document_name': 'tikifast', 'filename': './Policy/tikifast.txt'}
# --------------------------------------------------
# Chunk ID: tikifast_9
# Metadata: {'chunk_id': 9, 'created_at': '2025-03-21T16:19:28.422703', 'document_name': 'tikifast', 'filename': './Policy/tikifast.txt'}
# --------------------------------------------------
# Chunk ID: tikifast_10
# Metadata: {'chunk_id': 10, 'created_at': '2025-03-21T16:19:28.590015', 'document_name': 'tikifast', 'filename': './Policy/tikifast.txt'}
# --------------------------------------------------
# Chunk ID: tikifast_11
# Metadata: {'chunk_id': 11, 'created_at': '2025-03-21T16:19:28.736473', 'document_name': 'tikifast', 'filename': './Policy/tikifast.txt'}
# --------------------------------------------------
# Chunk ID: tikifast_12
# Metadata: {'chunk_id': 12, 'created_at': '2025-03-21T16:19:28.882944', 'document_name': 'tikifast', 'filename': './Policy/tikifast.txt'}
# --------------------------------------------------
# Chunk ID: tikifast_13
# Metadata: {'chunk_id': 13, 'created_at': '2025-03-21T16:19:29.036543', 'document_name': 'tikifast', 'filename': './Policy/tikifast.txt'}
# --------------------------------------------------
# Chunk ID: tikifast_14
# Metadata: {'chunk_id': 14, 'created_at': '2025-03-21T16:19:29.169224', 'document_name': 'tikifast', 'filename': './Policy/tikifast.txt'}
# --------------------------------------------------
# Chunk ID: tikifast_15
# Metadata: {'chunk_id': 15, 'created_at': '2025-03-21T16:19:29.344172', 'document_name': 'tikifast', 'filename': './Policy/tikifast.txt'}
# --------------------------------------------------
# Chunk ID: tikifast_16
# Metadata: {'chunk_id': 16, 'created_at': '2025-03-21T16:19:29.494732', 'document_name': 'tikifast', 'filename': './Policy/tikifast.txt'}
# --------------------------------------------------
# Chunk ID: tikifast_17
# Metadata: {'chunk_id': 17, 'created_at': '2025-03-21T16:19:29.665311', 'document_name': 'tikifast', 'filename': './Policy/tikifast.txt'}
# --------------------------------------------------
# Chunk ID: tikifast_18
# Metadata: {'chunk_id': 18, 'created_at': '2025-03-21T16:19:29.824849', 'document_name': 'tikifast', 'filename': './Policy/tikifast.txt'}
# --------------------------------------------------
# Chunk ID: tikinow_0
# Metadata: {'chunk_id': 0, 'created_at': '2025-03-21T16:19:30.011692', 'document_name': 'tikinow', 'filename': './Policy/tikinow.txt'}
# --------------------------------------------------
# Chunk ID: tikinow_1
# Metadata: {'chunk_id': 1, 'created_at': '2025-03-21T16:19:30.192689', 'document_name': 'tikinow', 'filename': './Policy/tikinow.txt'}
# --------------------------------------------------
# Chunk ID: tikinow_2
# Metadata: {'chunk_id': 2, 'created_at': '2025-03-21T16:19:30.391014', 'document_name': 'tikinow', 'filename': './Policy/tikinow.txt'}
# --------------------------------------------------
# Chunk ID: tikinow_3
# Metadata: {'chunk_id': 3, 'created_at': '2025-03-21T16:19:30.595727', 'document_name': 'tikinow', 'filename': './Policy/tikinow.txt'}
# --------------------------------------------------
# Chunk ID: tikinow_4
# Metadata: {'chunk_id': 4, 'created_at': '2025-03-21T16:19:30.758956', 'document_name': 'tikinow', 'filename': './Policy/tikinow.txt'}
# --------------------------------------------------
# Chunk ID: tikinow_5
# Metadata: {'chunk_id': 5, 'created_at': '2025-03-21T16:19:30.933957', 'document_name': 'tikinow', 'filename': './Policy/tikinow.txt'}
# --------------------------------------------------
# Chunk ID: tikinow_6
# Metadata: {'chunk_id': 6, 'created_at': '2025-03-21T16:19:31.116843', 'document_name': 'tikinow', 'filename': './Policy/tikinow.txt'}
# --------------------------------------------------

# %%
def delete_chunks_by_prefix(prefix):
    """Deletes all chunks from ChromaDB where the ID starts with the given prefix."""

    # Retrieve all stored metadata (including IDs)
    results = collection.get(include=["metadatas"])

    # Extract IDs that match the prefix
    chunk_ids_to_delete = [
        chunk_id for chunk_id in results["ids"] if chunk_id.startswith(prefix)
    ]

    # Delete matching chunks
    if chunk_ids_to_delete:
        collection.delete(ids=chunk_ids_to_delete)
        print(f"Deleted {len(chunk_ids_to_delete)} chunks with prefix '{prefix}' from ChromaDB.")
    else:
        print(f"No chunks found with prefix '{prefix}'.")

# # Example Usage
# delete_chunks_by_prefix("chinh_sach_giao_hang")  # Deletes all chunks where ID starts with 'tikifast'

# %%
# Load embedding model
model = SentenceTransformer("sentence-transformers/all-MiniLM-L12-v2")

def retrieve_chunks(query, top_k=5):
    """Retrieves the top_k most relevant chunks from ChromaDB based on the query."""

    # Generate embedding for the query
    query_embedding = model.encode(query).tolist()

    # Search for relevant chunks in ChromaDB
    results = collection.query(
        query_embeddings=[query_embedding],
        n_results=top_k,
        include=["metadatas", "documents"]
    )

    # Check if any documents were retrieved
    if not results.get("documents") or not results["documents"][0]:
        print("No relevant chunks found.")
        return []

    retrieved_chunks = []

    # Iterate through retrieved chunks
    for doc, metadata in zip(results["documents"][0], results.get("metadatas", [[]])[0]):
        metadata = metadata or {}  # Ensure metadata is a dictionary
        retrieved_chunks.append({"text": doc, "metadata": metadata})

    return retrieved_chunks
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/352 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
! pip install openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.66.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (2.10.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (2.27.2)

# %%
import openai

# Initialize OpenAI client
client = openai.OpenAI(api_key="")

def rewrite_query(query):
    """Rewrites a query for better retrieval in RAG."""

    response = client.chat.completions.create(
        model="gpt-4o-mini",  # OpenAI's GPT-4o-mini model
        messages=[{"role": "user", "content": f"Hãy viết lại câu query sau bằng tiếng Việt để hỗ trợ RAG chatbot: {query}"}],
        temperature=1,
        max_tokens=200
    )
    return response.choices[0].message.content

# Example usage
query = "How does AI impact business decision-making?"
print(rewrite_query(query))
# Out:
# Cách mà trí tuệ nhân tạo ảnh hưởng đến việc ra quyết định trong kinh doanh là gì?

# %%
def iterative_retrieval(query, iter=3):
    """Rewrite query iteratively, retrieve results, and remove duplicates."""

    seen_texts = set()
    retrieved_chunks = []

    for _ in range(iter):
        query = rewrite_query(query)
        chunks = retrieve_chunks(query)

        for chunk in chunks:
            text = chunk["text"]
            metadata = chunk["metadata"]

            # Only add chunks we haven't seen before
            if text not in seen_texts:
                seen_texts.add(text)
                retrieved_chunks.append({"text": text, "metadata": metadata})

    return retrieved_chunks

# %%
def reranker(query, chunks):
    """Reranks retrieved chunks using a cross-encoder."""

    cross_encoder = CrossEncoder("cross-encoder/ms-marco-MiniLM-L-6-v2")
    if not chunks:
        return []

    pairs = [(query, chunk["text"]) for chunk in chunks]
    scores = cross_encoder.predict(pairs)

    # Sort by score in descending order
    reranked_chunks = sorted(zip(chunks, scores), key=lambda x: x[1], reverse=True)

    # Return reranked chunks with scores
    return [{"text": chunk["text"], "metadata": chunk["metadata"], "score": score} for chunk, score in reranked_chunks]

# %%
def fetch_policies(query: str):
    retrieved_chunks = iterative_retrieval(query)
    reranked_chunks = reranker(query, retrieved_chunks)
    return_string = ""
    for chunk in reranked_chunks:
        return_string += chunk["text"] + "\n"
    return return_string

# %%
fetch_policies("policy trả hàng")
# Out:
# '\ufeffChính sách hậu mãi: Đổi mới, trả hàng hoàn tiền và bảo hành sản phẩm\n1. PHẠM VI VÀ ĐỐI TƯỢNG ÁP DỤNG\na. Đối tượng áp dụng\nChính Sách Hậu Mãi bao gồm đổi mới, trả hàng hoàn tiền và bảo hành sản phẩm (“Chính Sách Hậu Mãi”)  tại Tiki sẽ áp dụng đối với Khách Hàng khi thực hiện yêu cầu đổi mới, trả hàng, hoàn tiền và bảo hành sản phẩm mà Khách Hàng đã mua trên Sàn TMĐT Ti Ki.\nb. Phạm vi áp dụng\nb. Phạm vi áp dụng\nChính Sách Hậu Mãi tại Tiki sẽ quy định về quyền và nghĩa vụ của Khách Hàng trong việc đổi mới, trả hàng, hoàn tiền và bảo hành sản phẩm mà Khách Hàng đã mua trên Sàn TMĐT Ti Ki.\n3. Chính sách\na. Chính sách đặt hàng:\n \n* Giá bán sản phẩm đã bao gồm các phí, thuế phát sinh trong quá trình vận chuyển thông quan về Việt Nam và chưa bao gồm phí vận chuyển chặng cuối giao hàng trong lãnh thổ Việt Nam. Phí vận chuyển giao hàng trong lãnh thổ Việt Nam sẽ áp dụng theo chính sách giao hàng chung của Tiki đối với khách hàng đặt hàng.\n* Khách hàng có thể nhận diện sản phẩm mua trực tiếp từ nước ngoài bằng thông tin "Hàng quốc tế" tại phần thông tin chi tiết của sản phẩm.\n2. Đối tượng áp dụng\nKhách hàng mua hàng hóa từ nhà bán hàng ngoài lãnh thổ Việt Nam trên trang thương mại điện tử: https://tiki.vn\n \n3. Chính sách\na. Chính sách đặt hàng:\n2. ĐIỀU KIỆN ÁP DỤNG\nYêu cầu đổi trả, bảo hành của Khách Hàng được xem là hợp lệ khi đơn hàng và sản phẩm thỏa mãn các tiêu chí:\n(i) Khách Hàng yêu cầu thực hiện chính sách Hậu Mãi trong thời hạn quy định và điều kiện tại https://hotro.tiki.vn/s/article/chinh-sach-doi-tra-san-pham\n+ Nếu đơn hàng đã thông quan về Việt Nam: Tiki vẫn hỗ trợ hủy và hoàn lại giá trị đã thanh toán thực tế cho sản phẩm và phí vận chuyển (nếu có). Tuy nhiên, phần thuế phí nhập khẩu sẽ không được hoàn lại (trừ trường hợp yêu cầu hủy đơn hàng đến từ phía Tiki).\n   Ngày hiệu lực chính sách 24/05/2018, cập nhật lần cuối 15/10/2021.\n- Bảo hành chính hãng: khách hàng có thể mang sản phẩm đến trực tiếp hãng để bảo hành mà không cần thông qua Tiki.\n- Bảo hành thông qua Tiki: khách hàng liên hệ Tiki để được hỗ trợ tư vấn về bảo hành, Tiki sẽ xử lý thu hồi thông qua 2 cách:\n* Tiki sẽ đến thu hồi tận nơi với địa chỉ quý khách cung cấp.\nSau khi hoàn tất quá trình chọn phương thức thanh toán, vui lòng kiểm tra lại các thông tin sau: xuất hóa đơn VAT (nếu có), địa chỉ nhận hàng, giá khuyến mãi, tổng tiền.\nNếu các thông tin trên đã chính xác, quý khách vui lòng bấm “Đặt Mua”, hệ thống sẽ bắt đầu tiến hành tạo đơn hàng dựa trên các thông tin quý khách đã đăng ký.\nQuý khách có thể tham khảo thao tác đặt hàng tại đây:\nBước 4: Hoàn tất đóng gói.\n- Quý khách lưu ý không dán băng keo trực tiếp lên hộp của sản phẩm.\n- Ghi chú thông tin bên ngoài hộp đóng gói: mã đơn hàng, mã yêu cầu đổi trả, mã thu hồi.\n⚠️Lưu ý:\n- Đơn vị vận chuyển có thể từ chối nhận những sản phẩm hoàn trả chưa được đóng gói theo hướng dẫn trên.\nc. Chính sách hủy và hoàn tiền:\n   * Đối với đơn hàng có giá trị dưới 1.000.000 VNĐ: Tiki sẽ hoàn tiền toàn bộ giá trị đơn hàng với mọi lý do hủy đơn hàng.\n   * Đối với đơn hàng có giá trị trên 1.000.000 VNĐ:\n     + Nếu đơn hàng chưa thông quan về Việt Nam: Tiki hỗ trợ hủy đơn, hoàn toàn bộ giá trị đơn hàng cho khách hàng với bất kỳ lý do gì.\n'

# %%
policy_agent_system_message_vie = """
Bạn là một trợ lý hữu ích và có thể sử dụng công cụ để lấy thông tin về các chính sách của hiệu sách.
Nhiệm vụ của bạn là trả lời các câu hỏi liên quan đến chính sách.
"""
fetch_policies_tool = FunctionTool(
    fetch_policies, description="Lấy thông tin về các chính sách của hiệu sách."
)

policy_agent = AssistantAgent(
    name="policy_agent",
    description="Agent hỗ trợ trả lời các câu hỏi liên quan đến chính sách.",
    system_message=policy_agent_system_message_vie,
    model_client=model_client,
    tools=[fetch_policies_tool],
    reflect_on_tool_use=True, # Set to True to have the model reflect on the tool use, set to False to return the tool call result directly.
)

user_input = "Tôi đã đọc cuốn sách này xong rồi tuy nhiên không thích và muốn hoàn lại."
response = await policy_agent.on_messages([TextMessage(content=user_input, source="user")], CancellationToken())
print("Assistant:", response.chat_message.content)
print(response.inner_messages)
# Out:
# Assistant: Để hoàn trả cuốn sách mà bạn không thích, bạn cần đảm bảo rằng sản phẩm còn nguyên tình trạng như khi nhận, bao gồm hộp và bao bì đầy đủ, chưa qua sử dụng, và còn nguyên tem, mác hoặc niêm phong của nhà sản xuất (nếu có). Ngoài ra, bạn cũng cần kiểm tra xem cuốn sách đó có nằm trong danh mục hạn chế đổi trả hay không.
#
# Nếu bạn đáp ứng đủ các điều kiện trên, bạn có thể thực hiện yêu cầu hoàn trả theo chính sách của hiệu sách. Hãy chắc chắn rằng bạn thực hiện yêu cầu trong thời hạn quy định. Nếu cần thêm thông tin chi tiết, bạn có thể tham khảo trang chính sách đổi trả của hiệu sách.
# [ToolCallRequestEvent(source='policy_agent', models_usage=RequestUsage(prompt_tokens=122, completion_tokens=19), metadata={}, content=[FunctionCall(id='call_8pDZsxmQRrPvP34OLMsu0E8d', arguments='{"query":"hoàn trả sách"}', name='fetch_policies')], type='ToolCallRequestEvent'), ToolCallExecutionEvent(source='policy_agent', models_usage=None, metadata={}, content=[FunctionExecutionResult(content='\ufeffChính sách hậu mãi: Đổi mới, trả hàng hoàn tiền và bảo hành sản phẩm\n1. PHẠM VI VÀ ĐỐI TƯỢNG ÁP DỤNG\na. Đối tượng áp dụng\nChính Sách Hậu Mãi bao gồm đổi mới, trả hàng hoàn tiền và bảo hành sản phẩm (“Chính Sách Hậu Mãi”)  tại Tiki sẽ áp dụng đối với Khách Hàng khi thực hiện yêu cầu đổi mới, trả hàng, hoàn tiền và bảo hành sản phẩm mà Khách Hàng đã mua trên Sàn TMĐT Ti Ki.\nb. Phạm vi áp dụng\n(ii) Bổ sung hoặc sửa đổi danh sách các Sản Phẩm Hạn Chế Đổi Trả tại https://hotro.tiki.vn/s/article/chinh-sach-doi-tra-san-pham\n- Đối với sản phẩm sắc nhọn cần được bao gói lại các góc cạnh sắc nhọn, để đóng gói các sản phẩm này quý khách vui lòng tham khảo theo hướng dẫn sau:\nBước 4: Hoàn tất đóng gói\n - Quý khách lưu ý không dán băng keo trực tiếp lên hộp của sản phẩm.\n- Ghi chú thông tin bên ngoài hộp đóng gói: mã đơn hàng, mã yêu cầu đổi trả, mã thu hồi.\n+ Nếu đơn hàng đã thông quan về Việt Nam: Tiki vẫn hỗ trợ hủy và hoàn lại giá trị đã thanh toán thực tế cho sản phẩm và phí vận chuyển (nếu có). Tuy nhiên, phần thuế phí nhập khẩu sẽ không được hoàn lại (trừ trường hợp yêu cầu hủy đơn hàng đến từ phía Tiki).\n   Ngày hiệu lực chính sách 24/05/2018, cập nhật lần cuối 15/10/2021.\n3. Chính sách\na. Chính sách đặt hàng:\n \n* Giá bán sản phẩm đã bao gồm các phí, thuế phát sinh trong quá trình vận chuyển thông quan về Việt Nam và chưa bao gồm phí vận chuyển chặng cuối giao hàng trong lãnh thổ Việt Nam. Phí vận chuyển giao hàng trong lãnh thổ Việt Nam sẽ áp dụng theo chính sách giao hàng chung của Tiki đối với khách hàng đặt hàng.\nTiki bảo lưu quyền sửa đổi Chính sách Hậu Mãi vào bất cứ thời điểm nào, bao gồm:\n(i) Sửa đổi, chấm dứt hoặc đình chỉ Chính Sách Hậu Mãi của Tiki trong từng trường hợp, vào bất kỳ thời điểm nào theo quyết định của Tiki tại trang https://hotro.tiki.vn/s/article/chinh-sach-doi-tra-san-pham\n2. ĐIỀU KIỆN ÁP DỤNG\nYêu cầu đổi trả, bảo hành của Khách Hàng được xem là hợp lệ khi đơn hàng và sản phẩm thỏa mãn các tiêu chí:\n(i) Khách Hàng yêu cầu thực hiện chính sách Hậu Mãi trong thời hạn quy định và điều kiện tại https://hotro.tiki.vn/s/article/chinh-sach-doi-tra-san-pham\n* Điện tử: là chế độ bảo hành sản phẩm trực tuyến thay thế cho phương pháp bảo hành thông thường bằng giấy hay thẻ bảo hành bằng cách: nhắn tin SMS kích hoạt, quét mã QR-Code từ tem nhãn, đăng ký trên website hoặc bằng ứng dụng bảo hành.\nLÝ DO ĐỔI TRẢ\n\tĐIỀU KIỆN\n\tTrả do nhu cầu (đổi ý)\n\t- Sản phẩm còn nguyên tình trạng như khi nhận, hộp và bao bì còn đầy đủ và nguyên vẹn, sản phẩm chưa qua sử dụng, còn nguyên tem, mác hay niêm phong của nhà sản xuất (nếu có).\n- Còn đầy đủ phụ kiện, phiếu bảo hành cùng quà tặng kèm theo (nếu có) và chưa qua sử dụng.\n- Sản phẩm chưa được kích hoạt bảo hành điện tử.\n- Danh mục hạn chế đổi trả.: Nếu quý khách yêu cầu trả hàng do nhu cầu, sản phẩm không nằm trong danh mục hạn chế từ Tiki.\n', name='fetch_policies', call_id='call_8pDZsxmQRrPvP34OLMsu0E8d', is_error=False)], type='ToolCallExecutionEvent')]

# %% [markdown]
# # GroupChat

# %%
from typing import Sequence

from autogen_agentchat.agents import AssistantAgent, UserProxyAgent
from autogen_agentchat.conditions import MaxMessageTermination, TextMentionTermination
from autogen_agentchat.messages import AgentEvent, ChatMessage
from autogen_agentchat.teams import SelectorGroupChat
from autogen_agentchat.ui import Console
from autogen_ext.models.openai import OpenAIChatCompletionClient

text_mention_termination = TextMentionTermination("TERMINATE")
max_messages_termination = MaxMessageTermination(max_messages=25)
termination = text_mention_termination | max_messages_termination

selector_prompt = """Chọn một agent để thực hiện nhiệm vụ.

{roles}

Ngữ cảnh cuộc trò chuyện hiện tại:
{history}

Đọc cuộc trò chuyện ở trên, sau đó chọn một agent từ {participants} để thực hiện nhiệm vụ tiếp theo.
Chỉ chọn một tác nhân duy nhất.
"""

# %%
summarize_agent = AssistantAgent(
    "SummarizeAgent",
    model_client=model_client,
    system_message="""
    Bạn là đại diện của cửa hàng, người mà sẽ đưa ra câu trả lời cuối cùng cho khách hàng.
    Bạn sẽ nhận được thông tin từ các assistant agents.
    Nếu thông tin bạn nhận được liên quan đến quyển sách nào đó, bạn PHẢI yêu cầu một cách lịch sự khách hàng mua quyển sách đó.
    Còn nếu không, hãy tổng hợp lại thông tin từ các assistant agents và đưa ra câu trả lời một cách lịch sự cho khách hàng.
    Hãy trả lời "TERMINATE" khi kết thúc.
    """,
)

def selector_func(messages: Sequence[AgentEvent | ChatMessage]) -> str | None:
    # print(messages[-1].source)
    if messages[-1].source in ("sql_database_assistant", "policy_agent"):
        return summarize_agent.name
    if messages[-1].source == "user":
        return None

# Reset the previous team and run the chat again with the selector function.
# await team.reset()
team = SelectorGroupChat(
    [sql_database_assistant, policy_agent, summarize_agent],
    model_client=model_client,
    termination_condition=termination,
    selector_prompt=selector_prompt,
    allow_repeated_speaker=True,
    selector_func=selector_func,
)

task = "Tài xế cọc cằn, đánh khách hàng khi giao sách. Tôi muốn khiếu nại!"
await Console(team.run_stream(task=task))
# Out:
# ---------- user ----------
# Tài xế cọc cằn, đánh khách hàng khi giao sách. Tôi muốn khiếu nại!
# ---------- policy_agent ----------
# [FunctionCall(id='call_KW5mFQaQYJgqz241Oitvx1xL', arguments='{"query":"khiếu nại tài xế"}', name='fetch_policies')]
# ---------- policy_agent ----------
# [FunctionExecutionResult(content='* Người mua gửi khiếu nại tại địa chỉ:\nCông ty TNHH Ti Ki\nĐịa chỉ: 52 Út Tịch, phường 4, quận Tân Bình, thành phố Hồ Chí Minh\nQuý khách vui lòng đối chiếu thông tin mã thu hồi với nhân viên vận chuyển trước khi đưa hàng để đảm bảo đúng kiện hàng.\nĐể bảo vệ quyền lợi và tránh thất lạc hàng hóa, quý khách chỉ bàn giao kiện hàng cho nhân viên vận chuyển khi đảm bảo có 1 trong các điều kiện sau:\n- Nhân viên vận chuyển cung cấp giấy xác nhận thu hồi.\n2. ĐIỀU KIỆN ÁP DỤNG\nYêu cầu đổi trả, bảo hành của Khách Hàng được xem là hợp lệ khi đơn hàng và sản phẩm thỏa mãn các tiêu chí:\n(i) Khách Hàng yêu cầu thực hiện chính sách Hậu Mãi trong thời hạn quy định và điều kiện tại https://hotro.tiki.vn/s/article/chinh-sach-doi-tra-san-pham\nLÝ DO ĐỔI TRẢ\n\tĐIỀU KIỆN\n\tTrả do nhu cầu (đổi ý)\n\t- Sản phẩm còn nguyên tình trạng như khi nhận, hộp và bao bì còn đầy đủ và nguyên vẹn, sản phẩm chưa qua sử dụng, còn nguyên tem, mác hay niêm phong của nhà sản xuất (nếu có).\n- Còn đầy đủ phụ kiện, phiếu bảo hành cùng quà tặng kèm theo (nếu có) và chưa qua sử dụng.\n- Sản phẩm chưa được kích hoạt bảo hành điện tử.\n* Tiki sẽ đến thu hồi tận nơi với địa chỉ quý khách cung cấp.\n* Quý khách có thể chủ động đem sản phẩm tới HUB đổi/ trả/ bảo hành của Tiki tại địa chỉ: 52 Út Tịch, Phường 04, Quận Tân Bình, Thành phố Hồ Chí Minh để được xử lý.\n\ufeffHướng dẫn đóng gói sản phẩm để gửi trả hàng\nNhằm đảm bảo an toàn cho sản phẩm khi gửi về Tiki, quý khách vui lòng thực hiện đóng gói sản phẩm theo hướng dẫn sau:\n+ Địa chỉ thu hồi & thông tin liên lạc mặc định trùng khớp với địa chỉ nhận hàng\n+ Nếu cần đổi địa chỉ thu hồi hoặc thông tin liên lạc, quý khách có thể bấm “Thay đổi” để điền các thông tin cần thay đổi và bấm “Xác nhận”.\nBước 6: Bấm “Gửi yêu cầu” để hoàn tất tạo yêu cầu đổi trả.\n', name='fetch_policies', call_id='call_KW5mFQaQYJgqz241Oitvx1xL', is_error=False)]
# ---------- policy_agent ----------
# Nếu bạn muốn khiếu nại về tài xế đã có hành vi cọc cằn và đánh khách hàng khi giao sách, bạn có thể gửi khiếu nại đến Công ty TNHH Ti Ki theo địa chỉ sau:
#
# **Công ty TNHH Ti Ki**
# Địa chỉ: 52 Út Tịch, phường 4, quận Tân Bình, thành phố Hồ Chí Minh.
#
# Hãy chắc chắn cung cấp đầy đủ thông tin về sự việc, bao gồm thời gian, địa điểm và mô tả chi tiết về hành vi của tài xế để công ty có thể xử lý khiếu nại của bạn một cách hiệu quả. Nếu cần thêm thông tin hoặc hỗ trợ, bạn có thể liên hệ trực tiếp với dịch vụ khách hàng của công ty.
# ---------- SummarizeAgent ----------
# Cảm ơn bạn đã chia sẻ thông tin về sự việc không vui này. Để khiếu nại về tài xế có hành vi cọc cằn và đánh khách hàng khi giao sách, bạn có thể gửi khiếu nại đến Công ty TNHH Ti Ki theo địa chỉ sau:
#
# **Công ty TNHH Ti Ki**
# Địa chỉ: 52 Út Tịch, phường 4, quận Tân Bình, thành phố Hồ Chí Minh.
#
# Hãy cung cấp đầy đủ thông tin về sự việc, bao gồm thời gian, địa điểm và mô tả chi tiết về hành vi của tài xế để công ty có thể xử lý khiếu nại của bạn một cách hiệu quả. Nếu bạn cần thêm thông tin hoặc hỗ trợ, đừng ngần ngại liên hệ trực tiếp với dịch vụ khách hàng của công ty.
#
# TERMINATE
# TaskResult(messages=[TextMessage(source='user', models_usage=None, metadata={}, content='Tài xế cọc cằn, đánh khách hàng khi giao sách. Tôi muốn khiếu nại!', type='TextMessage'), ToolCallRequestEvent(source='policy_agent', models_usage=RequestUsage(prompt_tokens=1213, completion_tokens=23), metadata={}, content=[FunctionCall(id='call_KW5mFQaQYJgqz241Oitvx1xL', arguments='{"query":"khiếu nại tài xế"}', name='fetch_policies')], type='ToolCallRequestEvent'), ToolCallExecutionEvent(source='policy_agent', models_usage=None, metadata={}, content=[FunctionExecutionResult(content='* Người mua gửi khiếu nại tại địa chỉ:\nCông ty TNHH Ti Ki\nĐịa chỉ: 52 Út Tịch, phường 4, quận Tân Bình, thành phố Hồ Chí Minh\nQuý khách vui lòng đối chiếu thông tin mã thu hồi với nhân viên vận chuyển trước khi đưa hàng để đảm bảo đúng kiện hàng.\nĐể bảo vệ quyền lợi và tránh thất lạc hàng hóa, quý khách chỉ bàn giao kiện hàng cho nhân viên vận chuyển khi đảm bảo có 1 trong các điều kiện sau:\n- Nhân viên vận chuyển cung cấp giấy xác nhận thu hồi.\n2. ĐIỀU KIỆN ÁP DỤNG\nYêu cầu đổi trả, bảo hành của Khách Hàng được xem là hợp lệ khi đơn hàng và sản phẩm thỏa mãn các tiêu chí:\n(i) Khách Hàng yêu cầu thực hiện chính sách Hậu Mãi trong thời hạn quy định và điều kiện tại https://hotro.tiki.vn/s/article/chinh-sach-doi-tra-san-pham\nLÝ DO ĐỔI TRẢ\n\tĐIỀU KIỆN\n\tTrả do nhu cầu (đổi ý)\n\t- Sản phẩm còn nguyên tình trạng như khi nhận, hộp và bao bì còn đầy đủ và nguyên vẹn, sản phẩm chưa qua sử dụng, còn nguyên tem, mác hay niêm phong của nhà sản xuất (nếu có).\n- Còn đầy đủ phụ kiện, phiếu bảo hành cùng quà tặng kèm theo (nếu có) và chưa qua sử dụng.\n- Sản phẩm chưa được kích hoạt bảo hành điện tử.\n* Tiki sẽ đến thu hồi tận nơi với địa chỉ quý khách cung cấp.\n* Quý khách có thể chủ động đem sản phẩm tới HUB đổi/ trả/ bảo hành của Tiki tại địa chỉ: 52 Út Tịch, Phường 04, Quận Tân Bình, Thành phố Hồ Chí Minh để được xử lý.\n\ufeffHướng dẫn đóng gói sản phẩm để gửi trả hàng\nNhằm đảm bảo an toàn cho sản phẩm khi gửi về Tiki, quý khách vui lòng thực hiện đóng gói sản phẩm theo hướng dẫn sau:\n+ Địa chỉ thu hồi & thông tin liên lạc mặc định trùng khớp với địa chỉ nhận hàng\n+ Nếu cần đổi địa chỉ thu hồi hoặc thông tin liên lạc, quý khách có thể bấm “Thay đổi” để điền các thông tin cần thay đổi và bấm “Xác nhận”.\nBước 6: Bấm “Gửi yêu cầu” để hoàn tất tạo yêu cầu đổi trả.\n', name='fetch_policies', call_id='call_KW5mFQaQYJgqz241Oitvx1xL', is_error=False)], type='ToolCallExecutionEvent'), TextMessage(source='policy_agent', models_usage=RequestUsage(prompt_tokens=1757, completion_tokens=165), metadata={}, content='Nếu bạn muốn khiếu nại về tài xế đã có hành vi cọc cằn và đánh khách hàng khi giao sách, bạn có thể gửi khiếu nại đến Công ty TNHH Ti Ki theo địa chỉ sau:\n\n**Công ty TNHH Ti Ki**  \nĐịa chỉ: 52 Út Tịch, phường 4, quận Tân Bình, thành phố Hồ Chí Minh.\n\nHãy chắc chắn cung cấp đầy đủ thông tin về sự việc, bao gồm thời gian, địa điểm và mô tả chi tiết về hành vi của tài xế để công ty có thể xử lý khiếu nại của bạn một cách hiệu quả. Nếu cần thêm thông tin hoặc hỗ trợ, bạn có thể liên hệ trực tiếp với dịch vụ khách hàng của công ty.', type='TextMessage'), TextMessage(source='SummarizeAgent', models_usage=RequestUsage(prompt_tokens=322, completion_tokens=186), metadata={}, content='Cảm ơn bạn đã chia sẻ thông tin về sự việc không vui này. Để khiếu nại về tài xế có hành vi cọc cằn và đánh khách hàng khi giao sách, bạn có thể gửi khiếu nại đến Công ty TNHH Ti Ki theo địa chỉ sau:\n\n**Công ty TNHH Ti Ki**  \nĐịa chỉ: 52 Út Tịch, phường 4, quận Tân Bình, thành phố Hồ Chí Minh.\n\nHãy cung cấp đầy đủ thông tin về sự việc, bao gồm thời gian, địa điểm và mô tả chi tiết về hành vi của tài xế để công ty có thể xử lý khiếu nại của bạn một cách hiệu quả. Nếu bạn cần thêm thông tin hoặc hỗ trợ, đừng ngần ngại liên hệ trực tiếp với dịch vụ khách hàng của công ty. \n\nTERMINATE', type='TextMessage')], stop_reason="Text 'TERMINATE' mentioned")

# %%
task = "Tôi hủy đơn của cửa hàng bạn liên tiếp 10 lần rồi, liệu tôi có bị vào danh sách đen không?"
await Console(team.run_stream(task=task))
# Out:
# ---------- user ----------
# Tôi hủy đơn của cửa hàng bạn liên tiếp 10 lần rồi, liệu tôi có bị vào danh sách đen không?
# ---------- policy_agent ----------
# [FunctionCall(id='call_SuSHTYVj8WePj00dLSt98ppu', arguments='{"query":"hủy đơn hàng"}', name='fetch_policies')]
# ---------- policy_agent ----------
# [FunctionExecutionResult(content='c. Chính sách hủy và hoàn tiền:\n   * Đối với đơn hàng có giá trị dưới 1.000.000 VNĐ: Tiki sẽ hoàn tiền toàn bộ giá trị đơn hàng với mọi lý do hủy đơn hàng.\n   * Đối với đơn hàng có giá trị trên 1.000.000 VNĐ:\n     + Nếu đơn hàng chưa thông quan về Việt Nam: Tiki hỗ trợ hủy đơn, hoàn toàn bộ giá trị đơn hàng cho khách hàng với bất kỳ lý do gì.\n+ Nếu đơn hàng đã thông quan về Việt Nam: Tiki vẫn hỗ trợ hủy và hoàn lại giá trị đã thanh toán thực tế cho sản phẩm và phí vận chuyển (nếu có). Tuy nhiên, phần thuế phí nhập khẩu sẽ không được hoàn lại (trừ trường hợp yêu cầu hủy đơn hàng đến từ phía Tiki).\n   Ngày hiệu lực chính sách 24/05/2018, cập nhật lần cuối 15/10/2021.\n⚠️Lưu ý: Để các sản phẩm được giao thành một đơn hàng, quý khách cần đảm bảo đơn hàng thỏa các điều kiện:\n- Đặt các sản phẩm trong cùng một nhà bán hàng/ kho hàng.\n- Các sản phẩm trong giỏ hàng cần đặt trong một lần mua.\nSau khi quý khách đã có đủ sản phẩm cần đặt trong giỏ hàng, vui lòng áp dụng mã giảm giá (nếu có) và tiếp tục các bước sau để đặt hàng:\n\n* Chọn sản phẩm quý khách muốn mua và điều chỉnh số lượng phù hợp.\n* Bấm “Mua hàng” để bắt đầu đặt hàng.\nSau khi quý khách đã có đủ sản phẩm cần đặt trong giỏ hàng, tiếp tục các bước sau để đặt hàng:\n3. Chọn các sản phẩm khách hàng muốn đặt. \n4. Bấm “Mua hàng" để bắt đầu đặt hàng.\nQuý khách vui lòng đối chiếu thông tin mã thu hồi với nhân viên vận chuyển trước khi đưa hàng để đảm bảo đúng kiện hàng.\nĐể bảo vệ quyền lợi và tránh thất lạc hàng hóa, quý khách chỉ bàn giao kiện hàng cho nhân viên vận chuyển khi đảm bảo có 1 trong các điều kiện sau:\n- Nhân viên vận chuyển cung cấp giấy xác nhận thu hồi.\n* Khách hàng có thể nhận diện sản phẩm mua trực tiếp từ nước ngoài bằng thông tin "Hàng quốc tế" tại phần thông tin chi tiết của sản phẩm.\n2. Đối tượng áp dụng\nKhách hàng mua hàng hóa từ nhà bán hàng ngoài lãnh thổ Việt Nam trên trang thương mại điện tử: https://tiki.vn\n \n3. Chính sách\na. Chính sách đặt hàng:\nCác bên bao gồm Nhà Bán Hàng – người bán, Khách hàng – người mua có vai trò quan trọng và có trách nhiệm trong việc tích cực giải quyết sự việc. Nhà Bán Hàng cần có trách nhiệm cung cấp văn bản, tài liệu, giấy tờ, và các chứng cứ khác để chứng minh, làm rõ thông tin liên quan đến sự việc đang gây mâu thuẫn cho Khách hàng\n', name='fetch_policies', call_id='call_SuSHTYVj8WePj00dLSt98ppu', is_error=False)]
# ---------- policy_agent ----------
# Theo chính sách hủy đơn hàng, bạn có quyền hủy đơn hàng với bất kỳ lý do nào và sẽ được hoàn tiền toàn bộ giá trị đơn hàng nếu đơn hàng có giá trị dưới 1.000.000 VNĐ. Đối với đơn hàng có giá trị trên 1.000.000 VNĐ, bạn cũng có thể hủy đơn hàng và được hoàn tiền nếu đơn hàng chưa thông quan về Việt Nam.
#
# Tuy nhiên, việc hủy đơn hàng liên tiếp nhiều lần có thể khiến cửa hàng hoặc nền tảng thương mại điện tử xem xét hành vi của bạn. Mặc dù không có thông tin cụ thể về việc bị đưa vào danh sách đen, nhưng việc hủy đơn hàng quá nhiều có thể ảnh hưởng đến tài khoản của bạn trong tương lai.
#
# Nếu bạn lo lắng về việc này, bạn có thể liên hệ với dịch vụ khách hàng của cửa hàng để làm rõ và tìm hiểu thêm về chính sách của họ.
# ---------- SummarizeAgent ----------
# Cảm ơn bạn đã đặt câu hỏi. Theo chính sách hủy đơn hàng, bạn hoàn toàn có quyền hủy đơn hàng với bất kỳ lý do nào và sẽ được hoàn tiền toàn bộ nếu đơn hàng có giá trị dưới 1.000.000 VNĐ. Đối với đơn hàng có giá trị trên 1.000.000 VNĐ, bạn cũng có thể hủy và được hoàn tiền nếu đơn hàng chưa thông quan về Việt Nam.
#
# Tuy nhiên, việc hủy đơn hàng liên tiếp nhiều lần có thể khiến cửa hàng hoặc nền tảng thương mại điện tử xem xét hành vi của bạn. Mặc dù không có thông tin cụ thể về việc bị đưa vào danh sách đen, nhưng việc hủy đơn hàng quá nhiều có thể ảnh hưởng đến tài khoản của bạn trong tương lai.
#
# Nếu bạn lo lắng về vấn đề này, tôi khuyên bạn nên liên hệ với dịch vụ khách hàng của cửa hàng để làm rõ và tìm hiểu thêm về chính sách của họ.
#
# TERMINATE
# TaskResult(messages=[TextMessage(source='user', models_usage=None, metadata={}, content='Tôi hủy đơn của cửa hàng bạn liên tiếp 10 lần rồi, liệu tôi có bị vào danh sách đen không?', type='TextMessage'), ToolCallRequestEvent(source='policy_agent', models_usage=RequestUsage(prompt_tokens=2199, completion_tokens=19), metadata={}, content=[FunctionCall(id='call_SuSHTYVj8WePj00dLSt98ppu', arguments='{"query":"hủy đơn hàng"}', name='fetch_policies')], type='ToolCallRequestEvent'), ToolCallExecutionEvent(source='policy_agent', models_usage=None, metadata={}, content=[FunctionExecutionResult(content='c. Chính sách hủy và hoàn tiền:\n   * Đối với đơn hàng có giá trị dưới 1.000.000 VNĐ: Tiki sẽ hoàn tiền toàn bộ giá trị đơn hàng với mọi lý do hủy đơn hàng.\n   * Đối với đơn hàng có giá trị trên 1.000.000 VNĐ:\n     + Nếu đơn hàng chưa thông quan về Việt Nam: Tiki hỗ trợ hủy đơn, hoàn toàn bộ giá trị đơn hàng cho khách hàng với bất kỳ lý do gì.\n+ Nếu đơn hàng đã thông quan về Việt Nam: Tiki vẫn hỗ trợ hủy và hoàn lại giá trị đã thanh toán thực tế cho sản phẩm và phí vận chuyển (nếu có). Tuy nhiên, phần thuế phí nhập khẩu sẽ không được hoàn lại (trừ trường hợp yêu cầu hủy đơn hàng đến từ phía Tiki).\n   Ngày hiệu lực chính sách 24/05/2018, cập nhật lần cuối 15/10/2021.\n⚠️Lưu ý: Để các sản phẩm được giao thành một đơn hàng, quý khách cần đảm bảo đơn hàng thỏa các điều kiện:\n- Đặt các sản phẩm trong cùng một nhà bán hàng/ kho hàng.\n- Các sản phẩm trong giỏ hàng cần đặt trong một lần mua.\nSau khi quý khách đã có đủ sản phẩm cần đặt trong giỏ hàng, vui lòng áp dụng mã giảm giá (nếu có) và tiếp tục các bước sau để đặt hàng:\n\n* Chọn sản phẩm quý khách muốn mua và điều chỉnh số lượng phù hợp.\n* Bấm “Mua hàng” để bắt đầu đặt hàng.\nSau khi quý khách đã có đủ sản phẩm cần đặt trong giỏ hàng, tiếp tục các bước sau để đặt hàng:\n3. Chọn các sản phẩm khách hàng muốn đặt. \n4. Bấm “Mua hàng" để bắt đầu đặt hàng.\nQuý khách vui lòng đối chiếu thông tin mã thu hồi với nhân viên vận chuyển trước khi đưa hàng để đảm bảo đúng kiện hàng.\nĐể bảo vệ quyền lợi và tránh thất lạc hàng hóa, quý khách chỉ bàn giao kiện hàng cho nhân viên vận chuyển khi đảm bảo có 1 trong các điều kiện sau:\n- Nhân viên vận chuyển cung cấp giấy xác nhận thu hồi.\n* Khách hàng có thể nhận diện sản phẩm mua trực tiếp từ nước ngoài bằng thông tin "Hàng quốc tế" tại phần thông tin chi tiết của sản phẩm.\n2. Đối tượng áp dụng\nKhách hàng mua hàng hóa từ nhà bán hàng ngoài lãnh thổ Việt Nam trên trang thương mại điện tử: https://tiki.vn\n \n3. Chính sách\na. Chính sách đặt hàng:\nCác bên bao gồm Nhà Bán Hàng – người bán, Khách hàng – người mua có vai trò quan trọng và có trách nhiệm trong việc tích cực giải quyết sự việc. Nhà Bán Hàng cần có trách nhiệm cung cấp văn bản, tài liệu, giấy tờ, và các chứng cứ khác để chứng minh, làm rõ thông tin liên quan đến sự việc đang gây mâu thuẫn cho Khách hàng\n', name='fetch_policies', call_id='call_SuSHTYVj8WePj00dLSt98ppu', is_error=False)], type='ToolCallExecutionEvent'), TextMessage(source='policy_agent', models_usage=RequestUsage(prompt_tokens=2827, completion_tokens=197), metadata={}, content='Theo chính sách hủy đơn hàng, bạn có quyền hủy đơn hàng với bất kỳ lý do nào và sẽ được hoàn tiền toàn bộ giá trị đơn hàng nếu đơn hàng có giá trị dưới 1.000.000 VNĐ. Đối với đơn hàng có giá trị trên 1.000.000 VNĐ, bạn cũng có thể hủy đơn hàng và được hoàn tiền nếu đơn hàng chưa thông quan về Việt Nam.\n\nTuy nhiên, việc hủy đơn hàng liên tiếp nhiều lần có thể khiến cửa hàng hoặc nền tảng thương mại điện tử xem xét hành vi của bạn. Mặc dù không có thông tin cụ thể về việc bị đưa vào danh sách đen, nhưng việc hủy đơn hàng quá nhiều có thể ảnh hưởng đến tài khoản của bạn trong tương lai.\n\nNếu bạn lo lắng về việc này, bạn có thể liên hệ với dịch vụ khách hàng của cửa hàng để làm rõ và tìm hiểu thêm về chính sách của họ.', type='TextMessage'), TextMessage(source='SummarizeAgent', models_usage=RequestUsage(prompt_tokens=751, completion_tokens=210),  ...

# %%
task = "Hôm nay ăn gì?"
await Console(team.run_stream(task=task))
# Out:
# ---------- user ----------
# Hôm nay ăn gì?
# ---------- SummarizeAgent ----------
# Xin lỗi, nhưng tôi không thể cung cấp thông tin về thực phẩm hoặc gợi ý món ăn. Tuy nhiên, nếu bạn cần thông tin về một quyển sách nào đó, tôi rất sẵn lòng giúp đỡ! Bạn có muốn tìm hiểu về một quyển sách nào không?
#
# TERMINATE
# TaskResult(messages=[TextMessage(source='user', models_usage=None, metadata={}, content='Hôm nay ăn gì?', type='TextMessage'), TextMessage(source='SummarizeAgent', models_usage=RequestUsage(prompt_tokens=980, completion_tokens=64), metadata={}, content='Xin lỗi, nhưng tôi không thể cung cấp thông tin về thực phẩm hoặc gợi ý món ăn. Tuy nhiên, nếu bạn cần thông tin về một quyển sách nào đó, tôi rất sẵn lòng giúp đỡ! Bạn có muốn tìm hiểu về một quyển sách nào không? \n\nTERMINATE', type='TextMessage')], stop_reason="Text 'TERMINATE' mentioned")

# %%
task = "Hãng xe nào tốt nhất Việt Nam?"
await Console(team.run_stream(task=task))
# Out:
# ---------- user ----------
# Hãng xe nào tốt nhất Việt Nam?
# ---------- SummarizeAgent ----------
# Cảm ơn bạn đã đặt câu hỏi! Tuy nhiên, câu hỏi của bạn không liên quan đến sản phẩm hoặc dịch vụ của cửa hàng chúng tôi. Nếu bạn cần tư vấn về sách hoặc sản phẩm nào khác, hãy cho tôi biết, tôi rất sẵn lòng giúp đỡ!
#
# TERMINATE
# TaskResult(messages=[TextMessage(source='user', models_usage=None, metadata={}, content='Hãng xe nào tốt nhất Việt Nam?', type='TextMessage'), TextMessage(source='SummarizeAgent', models_usage=RequestUsage(prompt_tokens=913, completion_tokens=63), metadata={}, content='Cảm ơn bạn đã đặt câu hỏi! Tuy nhiên, câu hỏi của bạn không liên quan đến sản phẩm hoặc dịch vụ của cửa hàng chúng tôi. Nếu bạn cần tư vấn về sách hoặc sản phẩm nào khác, hãy cho tôi biết, tôi rất sẵn lòng giúp đỡ!\n\nTERMINATE', type='TextMessage')], stop_reason="Text 'TERMINATE' mentioned")

# %%
task = "Tên sách của đơn hàng gần nhất của tôi là gì?"
await Console(team.run_stream(task=task))
# Out:
# ---------- user ----------
# Tên sách của đơn hàng gần nhất của tôi là gì?
# ---------- sql_database_assistant ----------
# [FunctionCall(id='call_iNdzceqGbLVLspBFVrgQd11Q', arguments='{"query":"SELECT b.name FROM orders o JOIN books b ON o.book_id = b.id WHERE o.customer_id = 1 ORDER BY o.order_date DESC LIMIT 1;"}', name='execute_sql_query')]
# ---------- sql_database_assistant ----------
# [FunctionExecutionResult(content="[('Bài tập Bổ trợ Tiếng Anh 9 Right On!',)]", name='execute_sql_query', call_id='call_iNdzceqGbLVLspBFVrgQd11Q', is_error=False)]
# ---------- sql_database_assistant ----------
# Tên sách của đơn hàng gần nhất của bạn là "Bài tập Bổ trợ Tiếng Anh 9 Right On!".
# ---------- SummarizeAgent ----------
# Tên sách của đơn hàng gần nhất của bạn là "Bài tập Bổ trợ Tiếng Anh 9 Right On!". Nếu bạn quan tâm, bạn có thể mua quyển sách này hoặc tìm hiểu thêm về nó. Nếu bạn cần thêm thông tin, hãy cho tôi biết nhé!
#
# TERMINATE
# TaskResult(messages=[TextMessage(source='user', models_usage=None, metadata={}, content='Tên sách của đơn hàng gần nhất của tôi là gì?', type='TextMessage'), ToolCallRequestEvent(source='sql_database_assistant', models_usage=RequestUsage(prompt_tokens=1487, completion_tokens=48), metadata={}, content=[FunctionCall(id='call_iNdzceqGbLVLspBFVrgQd11Q', arguments='{"query":"SELECT b.name FROM orders o JOIN books b ON o.book_id = b.id WHERE o.customer_id = 1 ORDER BY o.order_date DESC LIMIT 1;"}', name='execute_sql_query')], type='ToolCallRequestEvent'), ToolCallExecutionEvent(source='sql_database_assistant', models_usage=None, metadata={}, content=[FunctionExecutionResult(content="[('Bài tập Bổ trợ Tiếng Anh 9 Right On!',)]", name='execute_sql_query', call_id='call_iNdzceqGbLVLspBFVrgQd11Q', is_error=False)], type='ToolCallExecutionEvent'), TextMessage(source='sql_database_assistant', models_usage=RequestUsage(prompt_tokens=1519, completion_tokens=26), metadata={}, content='Tên sách của đơn hàng gần nhất của bạn là "Bài tập Bổ trợ Tiếng Anh 9 Right On!".', type='TextMessage'), TextMessage(source='SummarizeAgent', models_usage=RequestUsage(prompt_tokens=1035, completion_tokens=62), metadata={}, content='Tên sách của đơn hàng gần nhất của bạn là "Bài tập Bổ trợ Tiếng Anh 9 Right On!". Nếu bạn quan tâm, bạn có thể mua quyển sách này hoặc tìm hiểu thêm về nó. Nếu bạn cần thêm thông tin, hãy cho tôi biết nhé!\n\nTERMINATE', type='TextMessage')], stop_reason="Text 'TERMINATE' mentioned")

# %%
task = "hãy giới thiệu cho tôi 5 quyển sách thuộc danh mục luật"
await Console(team.run_stream(task=task))
# Out:
# ---------- user ----------
# hãy giới thiệu cho tôi 5 quyển sách thuộc danh mục luật
# ---------- sql_database_assistant ----------
# Dưới đây là 5 quyển sách thuộc danh mục luật mà bạn có thể tham khảo:
#
# 1. Hệ Thống Toàn Văn Luật Đất Đai Và Các Nghị Định, Thông Tư, Quyết Định Hướng Dẫn Thi Hành
# 2. Pháp luật về môi giới, đầu tư kinh doanh bất động sản - nhà ở và đất đai
# 3. 101 Tư Vấn Pháp Luật Thường Thức Về Đất Đai (Tái Bản Lần 3 - 2020)
# 4. Pháp Luật Về Hợp Đồng - Các Vấn Đề Pháp Lý Cơ Bản - LS Trương Nhật Quang
# 5. Bộ Luật Lao Động Hiện Hành (Mới Nhất) Thông Qua Tại Kỳ Họp Thứ 8 Quốc Hội Khóa XIV
#
# Nếu bạn cần thêm thông tin về bất kỳ quyển sách nào, hãy cho tôi biết!
# ---------- SummarizeAgent ----------
# Dưới đây là 5 quyển sách thuộc danh mục luật mà bạn có thể tham khảo:
#
# 1. **Hệ Thống Toàn Văn Luật Đất Đai Và Các Nghị Định, Thông Tư, Quyết Định Hướng Dẫn Thi Hành**
# 2. **Pháp luật về môi giới, đầu tư kinh doanh bất động sản - nhà ở và đất đai**
# 3. **101 Tư Vấn Pháp Luật Thường Thức Về Đất Đai (Tái Bản Lần 3 - 2020)**
# 4. **Pháp Luật Về Hợp Đồng - Các Vấn Đề Pháp Lý Cơ Bản - LS Trương Nhật Quang**
# 5. **Bộ Luật Lao Động Hiện Hành (Mới Nhất) Thông Qua Tại Kỳ Họp Thứ 8 Quốc Hội Khóa XIV**
#
# Nếu bạn quan tâm đến một trong những quyển sách này, tôi rất khuyến khích bạn mua nó để có thêm kiến thức bổ ích! Bạn có muốn tìm hiểu thêm về quyển sách nào không?
#
# TERMINATE
# TaskResult(messages=[TextMessage(source='user', models_usage=None, metadata={}, content='hãy giới thiệu cho tôi 5 quyển sách thuộc danh mục luật', type='TextMessage'), TextMessage(source='sql_database_assistant', models_usage=RequestUsage(prompt_tokens=4147, completion_tokens=212), metadata={}, content='Dưới đây là 5 quyển sách thuộc danh mục luật mà bạn có thể tham khảo:\n\n1. Hệ Thống Toàn Văn Luật Đất Đai Và Các Nghị Định, Thông Tư, Quyết Định Hướng Dẫn Thi Hành\n2. Pháp luật về môi giới, đầu tư kinh doanh bất động sản - nhà ở và đất đai\n3. 101 Tư Vấn Pháp Luật Thường Thức Về Đất Đai (Tái Bản Lần 3 - 2020)\n4. Pháp Luật Về Hợp Đồng - Các Vấn Đề Pháp Lý Cơ Bản - LS Trương Nhật Quang\n5. Bộ Luật Lao Động Hiện Hành (Mới Nhất) Thông Qua Tại Kỳ Họp Thứ 8 Quốc Hội Khóa XIV\n\nNếu bạn cần thêm thông tin về bất kỳ quyển sách nào, hãy cho tôi biết!', type='TextMessage'), TextMessage(source='SummarizeAgent', models_usage=RequestUsage(prompt_tokens=1291, completion_tokens=245), metadata={}, content='Dưới đây là 5 quyển sách thuộc danh mục luật mà bạn có thể tham khảo:\n\n1. **Hệ Thống Toàn Văn Luật Đất Đai Và Các Nghị Định, Thông Tư, Quyết Định Hướng Dẫn Thi Hành**\n2. **Pháp luật về môi giới, đầu tư kinh doanh bất động sản - nhà ở và đất đai**\n3. **101 Tư Vấn Pháp Luật Thường Thức Về Đất Đai (Tái Bản Lần 3 - 2020)**\n4. **Pháp Luật Về Hợp Đồng - Các Vấn Đề Pháp Lý Cơ Bản - LS Trương Nhật Quang**\n5. **Bộ Luật Lao Động Hiện Hành (Mới Nhất) Thông Qua Tại Kỳ Họp Thứ 8 Quốc Hội Khóa XIV**\n\nNếu bạn quan tâm đến một trong những quyển sách này, tôi rất khuyến khích bạn mua nó để có thêm kiến thức bổ ích! Bạn có muốn tìm hiểu thêm về quyển sách nào không? \n\nTERMINATE', type='TextMessage')], stop_reason="Text 'TERMINATE' mentioned")

# %%
task = "tổng giá trị 3 đơn hàng gần nhất của tôi là bao nhiêu?"
await Console(team.run_stream(task=task))
# Out:
# ---------- user ----------
# tổng giá trị 3 đơn hàng gần nhất của tôi là bao nhiêu?
# ---------- sql_database_assistant ----------
# [FunctionCall(id='call_7dy4mdj6xuRie2Trbz9JBprI', arguments='{"query":"SELECT b.price FROM orders o JOIN books b ON o.book_id = b.id WHERE o.customer_id = 1 ORDER BY o.order_date DESC LIMIT 3;"}', name='execute_sql_query')]
# ---------- sql_database_assistant ----------
# [FunctionExecutionResult(content='[(81880,), (208000,), (139000,)]', name='execute_sql_query', call_id='call_7dy4mdj6xuRie2Trbz9JBprI', is_error=False)]
# ---------- sql_database_assistant ----------
# Tổng giá trị của 3 đơn hàng gần nhất của bạn là 81,880 + 208,000 + 139,000 = 428,880.
# ---------- SummarizeAgent ----------
# Tổng giá trị của 3 đơn hàng gần nhất của bạn là 428,880. Nếu bạn cần thêm thông tin hoặc hỗ trợ gì khác, hãy cho tôi biết nhé!
#
# TERMINATE
# TaskResult(messages=[TextMessage(source='user', models_usage=None, metadata={}, content='tổng giá trị 3 đơn hàng gần nhất của tôi là bao nhiêu?', type='TextMessage'), ToolCallRequestEvent(source='sql_database_assistant', models_usage=RequestUsage(prompt_tokens=2701, completion_tokens=48), metadata={}, content=[FunctionCall(id='call_7dy4mdj6xuRie2Trbz9JBprI', arguments='{"query":"SELECT b.price FROM orders o JOIN books b ON o.book_id = b.id WHERE o.customer_id = 1 ORDER BY o.order_date DESC LIMIT 3;"}', name='execute_sql_query')], type='ToolCallRequestEvent'), ToolCallExecutionEvent(source='sql_database_assistant', models_usage=None, metadata={}, content=[FunctionExecutionResult(content='[(81880,), (208000,), (139000,)]', name='execute_sql_query', call_id='call_7dy4mdj6xuRie2Trbz9JBprI', is_error=False)], type='ToolCallExecutionEvent'), TextMessage(source='sql_database_assistant', models_usage=RequestUsage(prompt_tokens=2729, completion_tokens=35), metadata={}, content='Tổng giá trị của 3 đơn hàng gần nhất của bạn là 81,880 + 208,000 + 139,000 = 428,880.', type='TextMessage'), TextMessage(source='SummarizeAgent', models_usage=RequestUsage(prompt_tokens=1884, completion_tokens=41), metadata={}, content='Tổng giá trị của 3 đơn hàng gần nhất của bạn là 428,880. Nếu bạn cần thêm thông tin hoặc hỗ trợ gì khác, hãy cho tôi biết nhé!\n\nTERMINATE', type='TextMessage')], stop_reason="Text 'TERMINATE' mentioned")

# %%
task = "hãy giới thiệu cho tôi 5 quyển sách thuộc danh mục phật giáo"
await Console(team.run_stream(task=task))
# Out:
# ---------- user ----------
# hãy giới thiệu cho tôi 5 quyển sách thuộc danh mục phật giáo
# ---------- sql_database_assistant ----------
# [FunctionCall(id='call_IMc3lVesarSNp81a93YTwBMM', arguments='{"query":"SELECT name FROM books WHERE categories LIKE \'%phật giáo%\' LIMIT 5;"}', name='execute_sql_query')]
# ---------- sql_database_assistant ----------
# [FunctionExecutionResult(content="[('Phật Thuyết Đại Thừa Vô Lượng Thọ Trang Nghiêm Thanh Tịnh Bình Đẳng Giác Kinh (Quyển 1)',), ('Lược Sử Tôn Giáo',), ('Sách Muôn Kiếp Nhân Sinh (Bìa Mềm) - Nguyên Phong',), ('Thiền Sư Và Em Bé 5 Tuổi',), ('Hành Trình Về Phương Đông (Tái Bản 2021)',)]", name='execute_sql_query', call_id='call_IMc3lVesarSNp81a93YTwBMM', is_error=False)]
# ---------- sql_database_assistant ----------
# Dưới đây là 5 quyển sách thuộc danh mục Phật giáo mà bạn có thể tham khảo:
#
# 1. Phật Thuyết Đại Thừa Vô Lượng Thọ Trang Nghiêm Thanh Tịnh Bình Đẳng Giác Kinh (Quyển 1)
# 2. Lược Sử Tôn Giáo
# 3. Sách Muôn Kiếp Nhân Sinh (Bìa Mềm) - Nguyên Phong
# 4. Thiền Sư Và Em Bé 5 Tuổi
# 5. Hành Trình Về Phương Đông (Tái Bản 2021)
#
# Nếu bạn cần thêm thông tin về bất kỳ quyển sách nào, hãy cho tôi biết!
# ---------- SummarizeAgent ----------
# Dưới đây là 5 quyển sách thuộc danh mục Phật giáo mà bạn có thể tham khảo:
#
# 1. **Phật Thuyết Đại Thừa Vô Lượng Thọ Trang Nghiêm Thanh Tịnh Bình Đẳng Giác Kinh (Quyển 1)**
# 2. **Lược Sử Tôn Giáo**
# 3. **Sách Muôn Kiếp Nhân Sinh (Bìa Mềm) - Nguyên Phong**
# 4. **Thiền Sư Và Em Bé 5 Tuổi**
# 5. **Hành Trình Về Phương Đông (Tái Bản 2021)**
#
# Nếu bạn quan tâm đến bất kỳ quyển sách nào trong danh sách trên, tôi rất khuyến khích bạn mua chúng để tìm hiểu thêm về Phật giáo. Nếu bạn cần thêm thông tin, hãy cho tôi biết nhé!
#
# TERMINATE
# TaskResult(messages=[TextMessage(source='user', models_usage=None, metadata={}, content='hãy giới thiệu cho tôi 5 quyển sách thuộc danh mục phật giáo', type='TextMessage'), ToolCallRequestEvent(source='sql_database_assistant', models_usage=RequestUsage(prompt_tokens=2889, completion_tokens=31), metadata={}, content=[FunctionCall(id='call_IMc3lVesarSNp81a93YTwBMM', arguments='{"query":"SELECT name FROM books WHERE categories LIKE \'%phật giáo%\' LIMIT 5;"}', name='execute_sql_query')], type='ToolCallRequestEvent'), ToolCallExecutionEvent(source='sql_database_assistant', models_usage=None, metadata={}, content=[FunctionExecutionResult(content="[('Phật Thuyết Đại Thừa Vô Lượng Thọ Trang Nghiêm Thanh Tịnh Bình Đẳng Giác Kinh (Quyển 1)',), ('Lược Sử Tôn Giáo',), ('Sách Muôn Kiếp Nhân Sinh (Bìa Mềm) - Nguyên Phong',), ('Thiền Sư Và Em Bé 5 Tuổi',), ('Hành Trình Về Phương Đông (Tái Bản 2021)',)]", name='execute_sql_query', call_id='call_IMc3lVesarSNp81a93YTwBMM', is_error=False)], type='ToolCallExecutionEvent'), TextMessage(source='sql_database_assistant', models_usage=RequestUsage(prompt_tokens=2994, completion_tokens=149), metadata={}, content='Dưới đây là 5 quyển sách thuộc danh mục Phật giáo mà bạn có thể tham khảo:\n\n1. Phật Thuyết Đại Thừa Vô Lượng Thọ Trang Nghiêm Thanh Tịnh Bình Đẳng Giác Kinh (Quyển 1)\n2. Lược Sử Tôn Giáo\n3. Sách Muôn Kiếp Nhân Sinh (Bìa Mềm) - Nguyên Phong\n4. Thiền Sư Và Em Bé 5 Tuổi\n5. Hành Trình Về Phương Đông (Tái Bản 2021)\n\nNếu bạn cần thêm thông tin về bất kỳ quyển sách nào, hãy cho tôi biết!', type='TextMessage'), TextMessage(source='SummarizeAgent', models_usage=RequestUsage(prompt_tokens=2112, completion_tokens=187), metadata={}, content='Dưới đây là 5 quyển sách thuộc danh mục Phật giáo mà bạn có thể tham khảo:\n\n1. **Phật Thuyết Đại Thừa Vô Lượng Thọ Trang Nghiêm Thanh Tịnh Bình Đẳng Giác Kinh (Quyển 1)**\n2. **Lược Sử Tôn Giáo**\n3. **Sách Muôn Kiếp Nhân Sinh (Bìa Mềm) - Nguyên Phong**\n4. **Thiền Sư Và Em Bé 5 Tuổi**\n5. **Hành Trình Về Phương Đông (Tái Bản 2021)**\n\nNếu bạn quan tâm đến bất kỳ quyển sách nào trong danh sách trên, tôi rất khuyến khích bạn mua chúng để tìm hiểu thêm về Phật giáo. Nếu bạn cần thêm thông tin, hãy cho tôi biết nhé!\n\nTERMINATE', type='TextMessage')], stop_reason="Text 'TERMINATE' mentioned")

# %%
task = "tôi vừa hỏi câu gì?"
await Console(team.run_stream(task=task))
# Out:
# ---------- user ----------
# tôi vừa hỏi câu gì?
# ---------- SummarizeAgent ----------
# Bạn đã hỏi về việc giới thiệu 5 quyển sách thuộc danh mục Phật giáo. Nếu bạn cần thêm thông tin hoặc có câu hỏi khác, hãy cho tôi biết!
#
# TERMINATE
# TaskResult(messages=[TextMessage(source='user', models_usage=None, metadata={}, content='tôi vừa hỏi câu gì?', type='TextMessage'), TextMessage(source='SummarizeAgent', models_usage=RequestUsage(prompt_tokens=1649, completion_tokens=41), metadata={}, content='Bạn đã hỏi về việc giới thiệu 5 quyển sách thuộc danh mục Phật giáo. Nếu bạn cần thêm thông tin hoặc có câu hỏi khác, hãy cho tôi biết! \n\nTERMINATE', type='TextMessage')], stop_reason="Text 'TERMINATE' mentioned")

# %%
task = "ăndgjángdfngdfngjdf"
await Console(team.run_stream(task=task))
# Out:
# ---------- user ----------
# ăndgjángdfngdfngjdf
# ---------- SummarizeAgent ----------
# Xin lỗi, có vẻ như bạn đã nhập một chuỗi ký tự không rõ ràng. Nếu bạn có câu hỏi hoặc yêu cầu nào cụ thể, hãy cho tôi biết để tôi có thể hỗ trợ bạn tốt hơn!
#
# TERMINATE
# TaskResult(messages=[TextMessage(source='user', models_usage=None, metadata={}, content='ăndgjángdfngdfngjdf', type='TextMessage'), TextMessage(source='SummarizeAgent', models_usage=RequestUsage(prompt_tokens=1713, completion_tokens=50), metadata={}, content='Xin lỗi, có vẻ như bạn đã nhập một chuỗi ký tự không rõ ràng. Nếu bạn có câu hỏi hoặc yêu cầu nào cụ thể, hãy cho tôi biết để tôi có thể hỗ trợ bạn tốt hơn! \n\nTERMINATE', type='TextMessage')], stop_reason="Text 'TERMINATE' mentioned")
